# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
jp797498e_twitter_entity_sentiment_analysis_path = kagglehub.dataset_download('jp797498e/twitter-entity-sentiment-analysis')

print('Data source import complete.')
# Out:
# Using Colab cache for faster access to the 'twitter-entity-sentiment-analysis' dataset.
# Data source import complete.

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, Dense, Embedding

from tensorflow.keras.optimizers import Adam

# %%
columns = ['id', 'country', 'label', 'text']
df = pd.read_csv("/kaggle/input/twitter-entity-sentiment-analysis/twitter_training.csv", names=columns)

# %%
df.head()
# Out:
#      id      country     label  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                 text
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74682 entries, 0 to 74681
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       74682 non-null  int64
#  1   country  74682 non-null  object
#  2   label    74682 non-null  object
#  3   text     73996 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.3+ MB

# %%
df = df.dropna(subset=['text'])

# %%
df.drop(columns=['id','country'])
# Out:
#           label                                               text
# 0      Positive  im getting on borderlands and i will murder yo...
# 1      Positive  I am coming to the borders and I will kill you...
# 2      Positive  im getting on borderlands and i will kill you ...
# 3      Positive  im coming on borderlands and i will murder you...
# 4      Positive  im getting on borderlands 2 and i will murder ...
# ...         ...                                                ...
# 74677  Positive  Just realized that the Windows partition of my...
# 74678  Positive  Just realized that my Mac window partition is ...
# 74679  Positive  Just realized the windows partition of my Mac ...
# 74680  Positive  Just realized between the windows partition of...
# 74681  Positive  Just like the windows partition of my Mac is l...
#
# [73996 rows x 2 columns]

# %%
df['label'].unique()
# Out:
# array(['Positive', 'Neutral', 'Negative', 'Irrelevant'], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(df[['label']])

# %%
tokenizer = Tokenizer()

tokenizer.fit_on_texts(df['text'])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'i': 2,
#  'to': 3,
#  'and': 4,
#  'a': 5,
#  'of': 6,
#  'is': 7,
#  'in': 8,
#  'for': 9,
#  'this': 10,
#  'it': 11,
#  'you': 12,
#  'on': 13,
#  'my': 14,
#  'that': 15,
#  'com': 16,
#  'with': 17,
#  'game': 18,
#  'so': 19,
#  'be': 20,
#  'me': 21,
#  'have': 22,
#  'just': 23,
#  'but': 24,
#  'not': 25,
#  'are': 26,
#  'all': 27,
#  'at': 28,
#  'was': 29,
#  'like': 30,
#  'out': 31,
#  'from': 32,
#  '2': 33,
#  'your': 34,
#  'pic': 35,
#  'twitter': 36,
#  'now': 37,
#  'get': 38,
#  'we': 39,
#  'as': 40,
#  'they': 41,
#  'has': 42,
#  'if': 43,
#  'one': 44,
#  'do': 45,
#  'good': 46,
#  't': 47,
#  'about': 48,
#  'can': 49,
#  'play': 50,
#  'no': 51,
#  'will': 52,
#  'an': 53,
#  'new': 54,
#  'really': 55,
#  'love': 56,
#  'when': 57,
#  'up': 58,
#  "i'm": 59,
#  'unk': 60,
#  'what': 61,
#  'more': 62,
#  'time': 63,
#  'by': 64,
#  'johnson': 65,
#  'how': 66,
#  'people': 67,
#  'some': 68,
#  'or': 69,
#  'why': 70,
#  '3': 71,
#  'see': 72,
#  'shit': 73,
#  "it's": 74,
#  'co': 75,
#  'been': 76,
#  'best': 77,
#  'still': 78,
#  'facebook': 79,
#  '’': 80,
#  'https': 81,
#  'got': 82,
#  'games': 83,
#  'go': 84,
#  '1': 85,
#  'great': 86,
#  'amazon': 87,
#  'even': 88,
#  'playing': 89,
#  'who': 90,
#  'xbox': 91,
#  'because': 92,
#  'fucking': 93,
#  'google': 94,
#  'fuck': 95,
#  'dead': 96,
#  'them': 97,
#  '4': 98,
#  'had': 99,
#  'please': 100,
#  'rhandlerr': 101,
#  'microsoft': 102,
#  'there': 103,
#  'us': 104,
#  'verizon': 105,
#  'only': 106,
#  'back': 107,
#  'tv': 108,
#  'much': 109,
#  'their': 110,
#  'our': 111,
#  'red': 112,
#  '5': 113,
#  'after': 114,
#  'going': 115,
#  'fifa': 116,
#  's': 117,
#  'he': 118,
#  'would': 119,
#  'am': 120,
#  'first': 121,
#  'know': 122,
#  'over': 123,
#  'its': 124,
#  "can't": 125,
#  "don't": 126,
#  'home': 127,
#  'make': 128,
#  'these': 129,
#  'pubg': 130,
#  'again': 131,
#  'very': 132,
#  'player': 133,
#  'twitch': 134,
#  'day': 135,
#  'fun': 136,
#  'than': 137,
#  'today': 138,
#  'here': 139,
#  'borderlands': 140,
#  '…': 141,
#  'nvidia': 142,
#  'gta': 143,
#  'also': 144,
#  'most': 145,
#  'want': 146,
#  'ever': 147,
#  'fix': 148,
#  'bad': 149,
#  '2020': 150,
#  'thank': 151,
#  'video': 152,
#  'never': 153,
#  'then': 154,
#  'call': 155,
#  'world': 156,
#  'battlefield': 157,
#  'ban': 158,
#  'overwatch': 159,
#  'wait': 160,
#  'thanks': 161,
#  'every': 162,
#  'series': 163,
#  'off': 164,
#  'right': 165,
#  'year': 166,
#  'watch': 167,
#  'too': 168,
#  'redemption': 169,
#  'x': 170,
#  'eamaddennfl': 171,
#  'think': 172,
#  'amazing': 173,
#  'getting': 174,
#  'team': 175,
#  'last': 176,
#  'being': 177,
#  'work': 178,
#  'his': 179,
#  'v': 180,
#  '10': 181,
#  'ps5': 182,
#  "i've": 183,
#  'nba2k': 184,
#  'u': 185,
#  'league': 186,
#  'rainbow6game': 187,
#  'news': 188,
#  'well': 189,
#  'live': 190,
#  'happy': 191,
#  'any': 192,
#  'guys': 193,
#  'into': 194,
#  'legends': 195,
#  'played': 196,
#  'youtu': 197,
#  'man': 198,
#  'help': 199,
#  'did': 200,
#  'black': 201,
#  'fortnite': 202,
#  'damn': 203,
#  'i’m': 204,
#  'youtube': 205,
#  'actually': 206,
#  'depot': 207,
#  'say': 208,
#  'always': 209,
#  'everyone': 210,
#  'looks': 211,
#  'next': 212,
#  'duty': 213,
#  'csgo': 214,
#  'stop': 215,
#  'years': 216,
#  'made': 217,
#  'need': 218,
#  'look': 219,
#  'another': 220,
#  'down': 221,
#  'players': 222,
#  'should': 223,
#  'big': 224,
#  'warcraft': 225,
#  'm': 226,
#  'come': 227,
#  'could': 228,
#  'creed': 229,
#  'while': 230,
#  'stream': 231,
#  'something': 232,
#  'were': 233,
#  'ghostrecon': 234,
#  'buy': 235,
#  'via': 236,
#  'which': 237,
#  'hearthstone': 238,
#  'way': 239,
#  'since': 240,
#  'same': 241,
#  'free': 242,
#  'other': 243,
#  'better': 244,
#  'many': 245,
#  'win': 246,
#  'nice': 247,
#  'finally': 248,
#  'already': 249,
#  'money': 250,
#  'excited': 251,
#  'him': 252,
#  'such': 253,
#  'online': 254,
#  'wow': 255,
#  'it’s': 256,
#  'thing': 257,
#  'life': 258,
#  'take': 259,
#  '100': 260,
#  '20': 261,
#  'hate': 262,
#  'lol': 263,
#  'two': 264,
#  'her': 265,
#  'update': 266,
#  'ass': 267,
#  'playstation': 268,
#  'support': 269,
#  '6': 270,
#  'give': 271,
#  'pc': 272,
#  'wtf': 273,
#  'store': 274,
#  'bit': 275,
#  'check': 276,
#  'before': 277,
#  'care': 278,
#  'italy': 279,
#  'keep': 280,
#  'ly': 281,
#  'awesome': 282,
#  'someone': 283,
#  'war': 284,
#  'oh': 285,
#  'having': 286,
#  'gonna': 287,
#  'doing': 288,
#  'top': 289,
#  'where': 290,
#  'does': 291,
#  'through': 292,
#  'days': 293,
#  'done': 294,
#  'lot': 295,
#  'cool': 296,
#  'old': 297,
#  'pretty': 298,
#  'feel': 299,
#  'night': 300,
#  'real': 301,
#  'health': 302,
#  'looking': 303,
#  'trying': 304,
#  'super': 305,
#  'dota': 306,
#  'im': 307,
#  'long': 308,
#  'access': 309,
#  'use': 310,
#  'playapex': 311,
#  'everything': 312,
#  'things': 313,
#  'hell': 314,
#  'both': 315,
#  'servers': 316,
#  'those': 317,
#  'ubisoft': 318,
#  'account': 319,
#  'making': 320,
#  'favorite': 321,
#  'nothing': 322,
#  'hey': 323,
#  'baby': 324,
#  'god': 325,
#  'said': 326,
#  'makes': 327,
#  'little': 328,
#  'literally': 329,
#  'guy': 330,
#  "that's": 331,
#  'season': 332,
#  '7': 333,
#  'cyberpunk': 334,
#  'anyone': 335,
#  'stupid': 336,
#  'card': 337,
#  'mobile': 338,
#  'worst': 339,
#  'week': 340,
#  'uk': 341,
#  'working': 342,
#  '2077': 343,
#  'hard': 344,
#  'start': 345,
#  'probably': 346,
#  'company': 347,
#  'gaming': 348,
#  'ops': 349,
#  'miss': 350,
#  'hope': 351,
#  'problem': 352,
#  'hours': 353,
#  'try': 354,
#  'show': 355,
#  'cold': 356,
#  'friends': 357,
#  'until': 358,
#  'phone': 359,
#  'almost': 360,
#  'against': 361,
#  'let': 362,
#  'ea': 363,
#  'won': 364,
#  'part': 365,
#  'find': 366,
#  "doesn't": 367,
#  'whole': 368,
#  'sure': 369,
#  'times': 370,
#  'service': 371,
#  'details': 372,
#  'few': 373,
#  'story': 374,
#  'around': 375,
#  'can’t': 376,
#  'anything': 377,
#  'banned': 378,
#  'cs': 379,
#  'yet': 380,
#  'app': 381,
#  'lost': 382,
#  'tell': 383,
#  'don’t': 384,
#  'apex': 385,
#  'beautiful': 386,
#  'powder': 387,
#  'crazy': 388,
#  'without': 389,
#  'tonight': 390,
#  '19': 391,
#  'd': 392,
#  'maybe': 393,
#  'full': 394,
#  'stuff': 395,
#  'own': 396,
#  'using': 397,
#  'end': 398,
#  'absolutely': 399,
#  'far': 400,
#  'internet': 401,
#  'pay': 402,
#  'open': 403,
#  'coming': 404,
#  '2k': 405,
#  'cant': 406,
#  'used': 407,
#  'interesting': 408,
#  'bf4db': 409,
#  'put': 410,
#  'enjoy': 411,
#  "didn't": 412,
#  'thought': 413,
#  'release': 414,
#  'ranked': 415,
#  'w': 416,
#  'fact': 417,
#  'ps4': 418,
#  'chance': 419,
#  'console': 420,
#  'community': 421,
#  'says': 422,
#  'went': 423,
#  'sad': 424,
#  'minutes': 425,
#  'may': 426,
#  'e': 427,
#  'she': 428,
#  '0': 429,
#  '21': 430,
#  'dont': 431,
#  "you're": 432,
#  'callofduty': 433,
#  'kill': 434,
#  'org': 435,
#  'business': 436,
#  'enough': 437,
#  'trash': 438,
#  'gameplay': 439,
#  '30': 440,
#  'gets': 441,
#  'order': 442,
#  'mode': 443,
#  'month': 444,
#  'epic': 445,
#  'point': 446,
#  "won't": 447,
#  'run': 448,
#  'wrong': 449,
#  'broken': 450,
#  'reason': 451,
#  "assassin's": 452,
#  'vaccine': 453,
#  'away': 454,
#  'content': 455,
#  'tt': 456,
#  'huge': 457,
#  'sorry': 458,
#  'read': 459,
#  'watching': 460,
#  'line': 461,
#  'y’all': 462,
#  'though': 463,
#  'bro': 464,
#  'post': 465,
#  'soon': 466,
#  'perfect': 467,
#  '12': 468,
#  'p': 469,
#  'due': 470,
#  'tried': 471,
#  'bought': 472,
#  'assassins': 473,
#  'cause': 474,
#  'match': 475,
#  'hit': 476,
#  'million': 477,
#  "i'll": 478,
#  'feels': 479,
#  '8': 480,
#  'change': 481,
#  'occurred': 482,
#  'music': 483,
#  'ago': 484,
#  'covid': 485,
#  'madden': 486,
#  'screen': 487,
#  'forward': 488,
#  'instead': 489,
#  'worth': 490,
#  'event': 491,
#  'skin': 492,
#  'grand': 493,
#  'able': 494,
#  '9': 495,
#  'seems': 496,
#  'myself': 497,
#  '15': 498,
#  'streaming': 499,
#  'might': 500,
#  'definitely': 501,
#  'cod': 502,
#  'i’ve': 503,
#  'net': 504,
#  'system': 505,
#  'morning': 506,
#  'friend': 507,
#  'price': 508,
#  'once': 509,
#  'during': 510,
#  'pro': 511,
#  'second': 512,
#  'services': 513,
#  'months': 514,
#  'found': 515,
#  'selling': 516,
#  'latest': 517,
#  'problems': 518,
#  "y'all": 519,
#  'tomorrow': 520,
#  'high': 521,
#  'yes': 522,
#  'launch': 523,
#  'wanted': 524,
#  'else': 525,
#  'name': 526,
#  'die': 527,
#  'started': 528,
#  'job': 529,
#  'currently': 530,
#  'mean': 531,
#  'terrible': 532,
#  'based': 533,
#  'comes': 534,
#  'person': 535,
#  'idea': 536,
#  'experience': 537,
#  'came': 538,
#  'seeing': 539,
#  'character': 540,
#  'power': 541,
#  'dota2': 542,
#  'fan': 543,
#  'saying': 544,
#  'place': 545,
#  'half': 546,
#  'seen': 547,
#  'needs': 548,
#  'data': 549,
#  'r': 550,
#  'face': 551,
#  'graphics': 552,
#  'took': 553,
#  'ok': 554,
#  '”': 555,
#  'level': 556,
#  'buying': 557,
#  'server': 558,
#  'funny': 559,
#  'exciting': 560,
#  'share': 561,
#  'follow': 562,
#  'remember': 563,
#  'luck': 564,
#  'wanna': 565,
#  'honestly': 566,
#  'worse': 567,
#  'called': 568,
#  'cards': 569,
#  'must': 570,
#  'join': 571,
#  'finished': 572,
#  'single': 573,
#  'taken': 574,
#  'seriously': 575,
#  'ift': 576,
#  'different': 577,
#  'list': 578,
#  'fans': 579,
#  'dlvr': 580,
#  'completely': 581,
#  'guess': 582,
#  '•': 583,
#  'playhearthstone': 584,
#  'proud': 585,
#  'c': 586,
#  'link': 587,
#  'pre': 588,
#  'patch': 589,
#  'yo': 590,
#  'warzone': 591,
#  'weekend': 592,
#  'talk': 593,
#  'sucks': 594,
#  'together': 595,
#  'homedepot': 596,
#  'kinda': 597,
#  'later': 598,
#  'shot': 599,
#  'odyssey': 600,
#  'tweet': 601,
#  'talc': 602,
#  'issues': 603,
#  'anymore': 604,
#  'three': 605,
#  'holy': 606,
#  'page': 607,
#  'entire': 608,
#  'hi': 609,
#  'windows': 610,
#  'social': 611,
#  'left': 612,
#  'eu': 613,
#  'lmao': 614,
#  'below': 615,
#  'hour': 616,
#  'gold': 617,
#  'trump': 618,
#  'wish': 619,
#  'yall': 620,
#  'birthday': 621,
#  'omg': 622,
#  'less': 623,
#  'moments': 624,
#  'trailer': 625,
#  'mad': 626,
#  'tech': 627,
#  'myteam': 628,
#  'set': 629,
#  're': 630,
#  'hear': 631,
#  'least': 632,
#  'loved': 633,
#  'kind': 634,
#  'despite': 635,
#  'switch': 636,
#  'taking': 637,
#  'sick': 638,
#  'waiting': 639,
#  'rewards': 640,
#  'understand': 641,
#  'annoying': 642,
#  'bitch': 643,
#  'ur': 644,
#  'easy': 645,
#  'incredible': 646,
#  'earned': 647,
#  'n': 648,
#  'family': 649,
#  'deal': 650,
#  'ghost': 651,
#  'leave': 652,
#  'movie': 653,
#  'believe': 654,
#  'saw': 655,
#  'points': 656,
#  'white': 657,
#  'bring': 658,
#  'move': 659,
#  "let's": 660,
#  'achievement': 661,
#  'running': 662,
#  'code': 663,
#  'ready': 664,
#  'congratulations': 665,
#  'each': 666,
#  'girl': 667,
#  'y': 668,
#  'glad': 669,
#  'killed': 670,
#  'cannot': 671,
#  'apple': 672,
#  'rtx': 673,
#  'action': 674,
#  'issue': 675,
#  'pass': 676,
#  'sometimes': 677,
#  'b': 678,
#  'n2k': 679,
#  'apps': 680,
#  'past': 681,
#  'breakpoint': 682,
#  'either': 683,
#  'early': 684,
#  'error': 685,
#  'welcome': 686,
#  'final': 687,
#  'class': 688,
#  'death': 689,
#  'daily': 690,
#  'smh': 691,
#  'blizzard': 692,
#  'told': 693,
#  'fortnitegame': 694,
#  'starting': 695,
#  'break': 696,
#  'living': 697,
#  'companies': 698,
#  'major': 699,
#  'videos': 700,
#  'quite': 701,
#  'sounds': 702,
#  'add': 703,
#  'toxic': 704,
#  'happened': 705,
#  'yeah': 706,
#  'yesterday': 707,
#  'small': 708,
#  'suck': 709,
#  'instagram': 710,
#  'goes': 711,
#  'house': 712,
#  'easports': 713,
#  'step': 714,
#  'gotta': 715,
#  'tired': 716,
#  'market': 717,
#  'giving': 718,
#  'boy': 719,
#  'under': 720,
#  'history': 721,
#  'review': 722,
#  'hot': 723,
#  'heart': 724,
#  'products': 725,
#  'group': 726,
#  'don': 727,
#  'truly': 728,
#  'j': 729,
#  'wikipedia': 730,
#  'edition': 731,
#  'battle': 732,
#  'gen': 733,
#  "we're": 734,
#  'bc': 735,
#  'fantastic': 736,
#  'totally': 737,
#  'customer': 738,
#  'nba': 739,
#  'version': 740,
#  'f': 741,
#  'india': 742,
#  'original': 743,
#  'mind': 744,
#  'global': 745,
#  'greatest': 746,
#  'modern': 747,
#  'true': 748,
#  'between': 749,
#  'number': 750,
#  'beta': 751,
#  'characters': 752,
#  'book': 753,
#  'talking': 754,
#  "what's": 755,
#  'delayed': 756,
#  'ubisoftsupport': 757,
#  'biggest': 758,
#  "haven't": 759,
#  '“': 760,
#  'car': 761,
#  'turn': 762,
#  'hello': 763,
#  'dude': 764,
#  'leagueoflegends': 765,
#  've': 766,
#  'article': 767,
#  'gift': 768,
#  'bullshit': 769,
#  'kills': 770,
#  'crap': 771,
#  'fire': 772,
#  'teams': 773,
#  'ronnie2k': 774,
#  'media': 775,
#  'especially': 776,
#  'complete': 777,
#  'fps': 778,
#  'sound': 779,
#  'main': 780,
#  'absolute': 781,
#  'behind': 782,
#  "they're": 783,
#  'updates': 784,
#  'longer': 785,
#  'decided': 786,
#  'drop': 787,
#  'thinking': 788,
#  'report': 789,
#  '11': 790,
#  'special': 791,
#  'kids': 792,
#  'gone': 793,
#  'keeps': 794,
#  'cute': 795,
#  'feeling': 796,
#  'email': 797,
#  "there's": 798,
#  'lose': 799,
#  'o': 800,
#  'city': 801,
#  'spend': 802,
#  'available': 803,
#  'franchise': 804,
#  'that’s': 805,
#  'clips': 806,
#  'connection': 807,
#  'pls': 808,
#  'id': 809,
#  'performance': 810,
#  'weeks': 811,
#  'sold': 812,
#  'sony': 813,
#  'late': 814,
#  'design': 815,
#  'beluba': 816,
#  'cancer': 817,
#  'close': 818,
#  'current': 819,
#  'released': 820,
#  'men': 821,
#  'okay': 822,
#  'en': 823,
#  'controller': 824,
#  'speed': 825,
#  'including': 826,
#  '3080': 827,
#  'wins': 828,
#  'star': 829,
#  'channel': 830,
#  'official': 831,
#  'alone': 832,
#  'shows': 833,
#  'works': 834,
#  'stay': 835,
#  'commission': 836,
#  'rt': 837,
#  'racist': 838,
#  '–': 839,
#  'plays': 840,
#  'garbage': 841,
#  'box': 842,
#  '000': 843,
#  'moment': 844,
#  'warfare': 845,
#  'random': 846,
#  'test': 847,
#  'low': 848,
#  'retweet': 849,
#  'art': 850,
#  'ya': 851,
#  'within': 852,
#  'word': 853,
#  'future': 854,
#  '24': 855,
#  'playoverwatch': 856,
#  'safe': 857,
#  'joke': 858,
#  'side': 859,
#  'massive': 860,
#  '50': 861,
#  'sell': 862,
#  'esports': 863,
#  'enjoyed': 864,
#  'women': 865,
#  'means': 866,
#  'search': 867,
#  'ridiculous': 868,
#  'head': 869,
#  'canada': 870,
#  'plus': 871,
#  'worked': 872,
#  'imagine': 873,
#  'cuz': 874,
#  'chat': 875,
#  'losing': 876,
#  'killing': 877,
#  'gamer': 878,
#  'website': 879,
#  'takes': 880,
#  'technology': 881,
#  'appreciate': 882,
#  'fast': 883,
#  'campaign': 884,
#  'spent': 885,
#  'computer': 886,
#  'information': 887,
#  'hero': 888,
#  'winning': 889,
#  'fake': 890,
#  'trust': 891,
#  'stopped': 892,
#  'tho': 893,
#  'yourself': 894,
#  'stock': 895,
#  'coronavirus': 896,
#  'customers': 897,
#  'possible': 898,
#  'disappointed': 899,
#  'gpu': 900,
#  'auto': 901,
#  'ai': 902,
#  'powerful': 903,
#  'control': 904,
#  'police': 905,
#  'government': 906,
#  'hyped': 907,
#  '99': 908,
#  'heard': 909,
#  'save': 910,
#  'item': 911,
#  'gave': 912,
#  'insane': 913,
#  'date': 914,
#  'map': 915,
#  'drive': 916,
#  'prime': 917,
#  'died': 918,
#  'wants': 919,
#  'nfl': 920,
#  'others': 921,
#  'twice': 922,
#  'dog': 923,
#  'become': 924,
#  'dear': 925,
#  'poverty': 926,
#  'ordered': 927,
#  'site': 928,
#  'quality': 929,
#  'exactly': 930,
#  'continue': 931,
#  'product': 932,
#  'geforce': 933,
#  'fight': 934,
#  'mixer': 935,
#  'stuck': 936,
#  'digital': 937,
#  'dark': 938,
#  'sweet': 939,
#  'rest': 940,
#  'happens': 941,
#  'lets': 942,
#  '14': 943,
#  'unit': 944,
#  'bugs': 945,
#  'forever': 946,
#  'dumb': 947,
#  'download': 948,
#  'party': 949,
#  'shooting': 950,
#  'boring': 951,
#  'g': 952,
#  "i'd": 953,
#  'boys': 954,
#  'seem': 955,
#  'iphone': 956,
#  'mut': 957,
#  'short': 958,
#  'somehow': 959,
#  'piece': 960,
#  'state': 961,
#  'trial': 962,
#  'song': 963,
#  'result': 964,
#  '25': 965,
#  'l': 966,
#  'weird': 967,
#  "isn't": 968,
#  'pick': 969,
#  'important': 970,
#  "he's": 971,
#  'broke': 972,
#  'valorant': 973,
#  'dlc': 974,
#  'actual': 975,
#  'voice': 976,
#  'log': 977,
#  'school': 978,
#  'matter': 979,
#  'sense': 980,
#  'chinese': 981,
#  'valhalla': 982,
#  'fine': 983,
#  'vs': 984,
#  '13': 985,
#  'cry': 986,
#  'lie': 987,
#  'listen': 988,
#  'missing': 989,
#  'finish': 990,
#  'loving': 991,
#  'tch': 992,
#  'activision': 993,
#  'received': 994,
#  'workers': 995,
#  '16': 996,
#  'simply': 997,
#  'except': 998,
#  'hold': 999,
#  'wonder': 1000,
#  ...}

# %%
sequences = tokenizer.texts_to_sequences(df['text'])
sequences
# Out:
# [[307, 174, 13, 140, 4, 2, 52, 1772, 12, 27],
#  [2, 120, 404, 3, 1, 6744, 4, 2, 52, 434, 12, 27],
#  [307, 174, 13, 140, 4, 2, 52, 434, 12, 27],
#  [307, 404, 13, 140, 4, 2, 52, 1772, 12, 27],
#  [307, 174, 13, 140, 33, 4, 2, 52, 1772, 12, 21, 27],
#  [307, 174, 194, 140, 4, 2, 49, 1772, 12, 27],
#  [19,
#   2,
#   885,
#   5,
#   373,
#   353,
#   320,
#   232,
#   9,
#   136,
#   43,
#   12,
#   126,
#   122,
#   2,
#   120,
#   5,
#   457,
#   140,
#   543,
#   4,
#   4209,
#   7,
#   44,
#   6,
#   14,
#   321,
#   752,
#   19,
#   2,
#   786,
#   3,
#   128,
#   497,
#   5,
#   6154,
#   9,
#   14,
#   272,
#   139,
#   7,
#   1,
#   743,
#   1899,
#   5145,
#   1,
#   9485,
#   2,
#   217,
#   411,
#   35,
#   36,
#   16,
#   18781],
#  [19,
#   2,
#   885,
#   5,
#   1019,
#   6,
#   353,
#   288,
#   232,
#   9,
#   136,
#   43,
#   12,
#   126,
#   122,
#   15,
#   59,
#   5,
#   457,
#   140,
#   543,
#   4,
#   4209,
#   7,
#   44,
#   6,
#   14,
#   321,
#   752,
#   2,
#   786,
#   3,
#   128,
#   5,
#   6154,
#   9,
#   14,
#   272,
#   1084,
#   1,
#   743,
#   1295,
#   1807,
#   3,
#   1,
#   9485,
#   2,
#   217,
#   22,
#   136,
#   35,
#   36,
#   16,
#   18781],
#  [19,
#   2,
#   885,
#   5,
#   373,
#   353,
#   288,
#   232,
#   9,
#   136,
#   43,
#   12,
#   126,
#   122,
#   59,
#   5,
#   457,
#   140,
#   543,
#   4,
#   4209,
#   7,
#   44,
#   6,
#   14,
#   321,
#   752],
#  [19,
#   2,
#   885,
#   5,
#   373,
#   353,
#   320,
#   232,
#   9,
#   136,
#   43,
#   12,
#   126,
#   122,
#   2,
#   120,
#   5,
#   457,
#   101,
#   543,
#   4,
#   4209,
#   7,
#   44,
#   6,
#   14,
#   321,
#   752,
#   19,
#   2,
#   786,
#   3,
#   128,
#   497,
#   5,
#   6154,
#   9,
#   14,
#   272,
#   139,
#   7,
#   1,
#   743,
#   1899,
#   5145,
#   1,
#   9485,
#   2,
#   217,
#   411,
#   35,
#   36,
#   16,
#   18781],
#  [1989,
#   19,
#   2,
#   885,
#   5,
#   373,
#   353,
#   320,
#   232,
#   9,
#   136,
#   43,
#   12,
#   126,
#   122,
#   2,
#   120,
#   5,
#   457,
#   101,
#   543,
#   4,
#   4209,
#   7,
#   44,
#   6,
#   14,
#   321,
#   752,
#   19,
#   2,
#   786,
#   3,
#   128,
#   497,
#   5,
#   6154,
#   9,
#   14,
#   272,
#   139,
#   7,
#   1,
#   743,
#   1899,
#   5145,
#   1,
#   9485,
#   2,
#   217,
#   411,
#   35,
#   36,
#   16,
#   18781],
#  [29],
#  [1679, 344, 1680, 18782, 3318, 903, 1922, 7812, 140, 71, 91, 580, 11, 10156],
#  [1679, 344, 1680, 18782, 3318, 903, 1922, 7812, 140, 71, 91, 580, 11, 10156],
#  [1679, 344, 1680, 18782, 3318, 903, 1922, 7812, 140, 71, 91, 9486, 11, 10156],
#  [1679,
#   344,
#   1680,
#   6745,
#   3318,
#   24,
#   903,
#   1922,
#   7812,
#   140,
#   85,
#   91,
#   580,
#   11,
#   10156],
#  [190,
#   1679,
#   344,
#   483,
#   1680,
#   1680,
#   18782,
#   3318,
#   1,
#   903,
#   190,
#   1922,
#   2,
#   7812,
#   140,
#   71,
#   3910,
#   91,
#   580,
#   32,
#   11,
#   427,
#   10156],
#  [2, 344, 30, 21, 3318, 4111, 1229, 1922, 2383, 140, 71, 91, 580, 11, 10156],
#  [15,
#   29,
#   1,
#   121,
#   140,
#   1756,
#   8,
#   5,
#   308,
#   63,
#   290,
#   2,
#   206,
#   99,
#   5,
#   55,
#   2462,
#   2125,
#   537,
#   2,
#   82,
#   68,
#   55,
#   46,
#   770],
#  [10,
#   29,
#   1,
#   121,
#   140,
#   1756,
#   8,
#   5,
#   308,
#   63,
#   290,
#   2,
#   206,
#   99,
#   5,
#   55,
#   2462,
#   1865,
#   537,
#   2,
#   82,
#   68,
#   55,
#   46,
#   770],
#  [15,
#   29,
#   1,
#   121,
#   140,
#   1756,
#   8,
#   5,
#   308,
#   63,
#   290,
#   2,
#   206,
#   99,
#   5,
#   55,
#   2462,
#   2125,
#   537,
#   2,
#   82,
#   68,
#   55,
#   46,
#   770],
#  [15,
#   29,
#   1,
#   121,
#   140,
#   1756,
#   8,
#   5,
#   308,
#   63,
#   290,
#   2,
#   206,
#   864,
#   5,
#   55,
#   2462,
#   2125,
#   537,
#   2,
#   82,
#   68,
#   1110,
#   46,
#   770],
#  [15,
#   2,
#   29,
#   1,
#   121,
#   301,
#   140,
#   1756,
#   8,
#   5,
#   247,
#   308,
#   160,
#   63,
#   290,
#   2,
#   206,
#   99,
#   5,
#   55,
#   2462,
#   2125,
#   537,
#   4,
#   2,
#   82,
#   68,
#   55,
#   46,
#   770],
#  [15,
#   29,
#   1,
#   121,
#   140,
#   1756,
#   8,
#   5,
#   723,
#   1011,
#   290,
#   2,
#   206,
#   99,
#   5,
#   55,
#   149,
#   2125,
#   537,
#   2,
#   200,
#   68,
#   55,
#   46,
#   770],
#  [1, 758, 18783, 8, 14, 258, 538, 31, 5, 166, 484, 95, 140, 71],
#  [1, 758, 1879, 6, 14, 258, 538, 5, 166, 484],
#  [1, 758, 1879, 6, 14, 258, 538, 5, 166, 484],
#  [1, 758, 18783, 8, 14, 258, 404, 31, 5, 166, 484, 95, 140, 71],
#  [9,
#   1,
#   758,
#   4504,
#   18783,
#   8,
#   14,
#   258,
#   538,
#   1880,
#   31,
#   5,
#   166,
#   63,
#   484,
#   95,
#   140,
#   71],
#  [1, 758, 18783, 8, 14, 258, 538, 107, 176, 166, 484, 95, 140, 176],
#  [39,
#   572,
#   140,
#   71,
#   248,
#   7813,
#   151,
#   12,
#   9,
#   1880,
#   31,
#   210,
#   11,
#   29,
#   136,
#   2,
#   52,
#   354,
#   3,
#   231,
#   520,
#   24,
#   43,
#   25,
#   2,
#   500,
#   19,
#   68,
#   2421,
#   1681,
#   230,
#   18784,
#   39,
#   2946,
#   72,
#   151,
#   12,
#   19,
#   109,
#   9,
#   1,
#   3712,
#   10157,
#   10158,
#   18785,
#   4,
#   22281],
#  [39,
#   248,
#   248,
#   366,
#   140,
#   71,
#   522,
#   151,
#   12,
#   27,
#   9,
#   1880,
#   31,
#   11,
#   29,
#   136,
#   478,
#   354,
#   3,
#   231,
#   520,
#   24,
#   43,
#   25,
#   393,
#   68,
#   2421,
#   1681,
#   2048,
#   72,
#   161,
#   9,
#   1,
#   3712,
#   10157,
#   10158,
#   18785,
#   4,
#   22281],
#  [151,
#   12,
#   9,
#   1880,
#   58,
#   210,
#   11,
#   29,
#   136,
#   478,
#   354,
#   3,
#   38,
#   5,
#   8893,
#   520,
#   24,
#   43,
#   11,
#   1467,
#   9,
#   21,
#   68,
#   2421,
#   1681,
#   119,
#   78,
#   20,
#   8,
#   18786,
#   2048,
#   72,
#   151,
#   12,
#   19,
#   109,
#   9,
#   1,
#   10157,
#   10158,
#   26652,
#   4,
#   26653,
#   3712],
#  [39,
#   572,
#   140,
#   71,
#   266,
#   7813,
#   151,
#   12,
#   9,
#   1880,
#   31,
#   193,
#   11,
#   29,
#   136,
#   2,
#   52,
#   354,
#   3,
#   231,
#   4,
#   88,
#   43,
#   25,
#   2,
#   500,
#   19,
#   68,
#   2421,
#   1681,
#   230,
#   18784,
#   39,
#   2946,
#   84,
#   151,
#   12,
#   19,
#   109,
#   9,
#   1,
#   3712,
#   10157,
#   10158,
#   18785,
#   4,
#   351],
#  [39,
#   572,
#   140,
#   71,
#   4,
#   248,
#   7813,
#   151,
#   12,
#   210,
#   9,
#   1880,
#   31,
#   210,
#   11,
#   29,
#   136,
#   2,
#   52,
#   354,
#   3,
#   128,
#   231,
#   520,
#   24,
#   43,
#   25,
#   2,
#   500,
#   128,
#   19,
#   68,
#   2421,
#   1681,
#   230,
#   18784,
#   181,
#   39,
#   153,
#   2946,
#   72,
#   151,
#   12,
#   315,
#   19,
#   109,
#   9,
#   1,
#   3712,
#   10157,
#   10158,
#   69,
#   18785,
#   4,
#   98,
#   22281],
#  [39,
#   572,
#   140,
#   71,
#   248,
#   7813,
#   323,
#   12,
#   9,
#   1880,
#   31,
#   19,
#   11,
#   29,
#   136,
#   2,
#   52,
#   354,
#   15,
#   231,
#   520,
#   4,
#   43,
#   25,
#   2,
#   500,
#   310,
#   68,
#   2421,
#   1681,
#   32,
#   18784,
#   39,
#   2946,
#   72,
#   151,
#   12,
#   19,
#   109,
#   66,
#   245,
#   3712,
#   10157,
#   10158,
#   200,
#   4,
#   110],
#  [198,
#   3625,
#   55,
#   548,
#   3,
#   148,
#   10,
#   22282,
#   1340,
#   8,
#   1,
#   54,
#   140,
#   71,
#   974,
#   406,
#   20,
#   983,
#   3,
#   3532,
#   4646,
#   13,
#   2102,
#   181,
#   3,
#   38,
#   85,
#   1190,
#   787,
#   230,
#   1275,
#   525,
#   2,
#   38,
#   270,
#   181,
#   1340,
#   55,
#   594,
#   2947],
#  [198,
#   3625,
#   55,
#   548,
#   3,
#   148,
#   129,
#   1550,
#   1340,
#   8,
#   1,
#   54,
#   140,
#   71,
#   974,
#   9,
#   3532,
#   4646,
#   13,
#   2102,
#   181,
#   3,
#   38,
#   5,
#   1190,
#   787,
#   230,
#   2,
#   38,
#   270,
#   181,
#   1340,
#   6431],
#  [198,
#   3625,
#   55,
#   548,
#   3,
#   148,
#   10,
#   26654,
#   1340,
#   8,
#   1,
#   54,
#   140,
#   71,
#   974,
#   406,
#   20,
#   983,
#   3,
#   3532,
#   4646,
#   13,
#   2102,
#   181,
#   3,
#   38,
#   85,
#   1190,
#   787,
#   230,
#   6431,
#   2,
#   38,
#   270,
#   181,
#   1340,
#   55,
#   594,
#   2947],
#  [198,
#   3205,
#   55,
#   548,
#   3,
#   148,
#   10,
#   22282,
#   1340,
#   4,
#   1,
#   54,
#   140,
#   71,
#   11,
#   406,
#   20,
#   983,
#   3,
#   3532,
#   4646,
#   13,
#   2102,
#   181,
#   3,
#   38,
#   85,
#   1190,
#   787,
#   230,
#   1275,
#   525,
#   2,
#   38,
#   270,
#   181,
#   1340,
#   55,
#   594],
#  [198,
#   3625,
#   55,
#   548,
#   3,
#   148,
#   10,
#   22282,
#   1340,
#   8,
#   1,
#   581,
#   54,
#   140,
#   71,
#   293,
#   974,
#   2,
#   406,
#   427,
#   20,
#   983,
#   286,
#   3,
#   20,
#   3532,
#   4646,
#   13,
#   2102,
#   181,
#   3,
#   427,
#   38,
#   85,
#   1190,
#   2836,
#   787,
#   230,
#   1275,
#   525,
#   2,
#   38,
#   270,
#   181,
#   1340,
#   11,
#   55,
#   594,
#   3,
#   2947],
#  [60,
#   3625,
#   55,
#   63,
#   3,
#   148,
#   10,
#   181,
#   1340,
#   8,
#   1,
#   54,
#   140,
#   71,
#   974,
#   69,
#   20,
#   983,
#   3,
#   1296,
#   4646,
#   13,
#   2102,
#   181,
#   3,
#   38,
#   5,
#   1190,
#   787,
#   230,
#   210,
#   525,
#   2,
#   38,
#   270,
#   181,
#   1340,
#   55,
#   548,
#   2947],
#  [276, 31, 10, 445, 1382],
#  [276, 31, 10, 445, 1382],
#  [167, 10, 445, 24229],
#  [276, 31, 111, 445, 1382],
#  [276, 31, 10, 224, 445, 1382],
#  [276, 60, 10, 445, 1382],
#  [6432,
#   3373,
#   9,
#   22283,
#   5,
#   328,
#   275,
#   6,
#   140,
#   2,
#   82,
#   568,
#   8,
#   684,
#   9,
#   178,
#   520,
#   19,
#   2,
#   125,
#   128,
#   58,
#   63,
#   458,
#   14,
#   1866,
#   134,
#   108,
#   18787],
#  [5,
#   275,
#   6,
#   6155,
#   2,
#   29,
#   568,
#   3,
#   178,
#   520,
#   506,
#   19,
#   2,
#   125,
#   1825,
#   58,
#   458,
#   14,
#   56,
#   134,
#   108,
#   18787],
#  [2948,
#   6,
#   26655,
#   5,
#   275,
#   6,
#   5,
#   8383,
#   2,
#   29,
#   568,
#   3,
#   178,
#   684,
#   520,
#   19,
#   2,
#   125,
#   1825,
#   58],
#  [6432,
#   3373,
#   9,
#   22283,
#   5,
#   328,
#   275,
#   6,
#   140,
#   2,
#   82,
#   568,
#   8,
#   684,
#   9,
#   178,
#   520,
#   19,
#   2,
#   125,
#   128,
#   58,
#   63,
#   458,
#   14,
#   1866,
#   134,
#   108,
#   18787],
#  [9,
#   6432,
#   3373,
#   9,
#   22283,
#   5,
#   328,
#   275,
#   6,
#   140,
#   2,
#   82,
#   568,
#   8,
#   684,
#   9,
#   178,
#   520,
#   19,
#   2,
#   125,
#   128,
#   58,
#   63,
#   458,
#   14,
#   1866,
#   134,
#   108,
#   18787],
#  [27],
#  [70,
#   291,
#   30,
#   162,
#   198,
#   8,
#   140,
#   22,
#   18788,
#   107,
#   1283,
#   1520,
#   12,
#   909,
#   6,
#   13945,
#   12,
#   336,
#   2493],
#  [70, 30, 162, 198, 8, 2422, 3319, 22, 12, 25, 909, 6, 13945, 12, 336, 2493],
#  [70,
#   30,
#   210,
#   525,
#   8,
#   1,
#   2422,
#   3319,
#   22,
#   34,
#   1283,
#   3374,
#   164,
#   22,
#   12,
#   25,
#   909,
#   15,
#   12,
#   26,
#   336,
#   4347],
#  [70,
#   291,
#   30,
#   60,
#   198,
#   8,
#   140,
#   22,
#   18788,
#   107,
#   1283,
#   69,
#   12,
#   909,
#   6,
#   13945,
#   12,
#   336,
#   2493],
#  [70,
#   8384,
#   291,
#   30,
#   162,
#   198,
#   8,
#   140,
#   22,
#   428,
#   18788,
#   15,
#   107,
#   1283,
#   2733,
#   80,
#   47,
#   12,
#   909,
#   437,
#   6,
#   7269,
#   13945,
#   12,
#   336,
#   2493],
#  [70,
#   291,
#   4813,
#   162,
#   198,
#   8,
#   13946,
#   22,
#   18788,
#   107,
#   1283,
#   1520,
#   12,
#   909,
#   6,
#   13945,
#   1,
#   2577,
#   2493],
#  [],
#  [],
#  [2605],
#  [],
#  [61],
#  [115,
#   3,
#   990,
#   58,
#   140,
#   33,
#   138,
#   183,
#   82,
#   68,
#   54,
#   3713,
#   629,
#   58,
#   4,
#   120,
#   303,
#   488,
#   3,
#   5,
#   46,
#   231,
#   695,
#   8,
#   48,
#   120,
#   616],
#  [2,
#   52,
#   990,
#   140,
#   33,
#   138,
#   2,
#   22,
#   68,
#   54,
#   3713,
#   629,
#   58,
#   4,
#   120,
#   303,
#   488,
#   3,
#   5,
#   46,
#   231,
#   345,
#   8,
#   48,
#   53,
#   616],
#  [59,
#   115,
#   3,
#   990,
#   140,
#   33,
#   138,
#   2,
#   22,
#   68,
#   54,
#   3713,
#   1808,
#   4,
#   59,
#   303,
#   488,
#   3,
#   5,
#   46,
#   231],
#  [115,
#   3,
#   990,
#   58,
#   140,
#   33,
#   138,
#   183,
#   82,
#   68,
#   54,
#   1419,
#   629,
#   58,
#   4,
#   120,
#   219,
#   488,
#   3,
#   5,
#   46,
#   231,
#   695,
#   8,
#   48,
#   261,
#   616],
#  [115,
#   3,
#   990,
#   990,
#   6156,
#   58,
#   140,
#   33,
#   138,
#   183,
#   23,
#   82,
#   265,
#   68,
#   54,
#   3713,
#   629,
#   27,
#   58,
#   4,
#   120,
#   303,
#   488,
#   11,
#   3,
#   5,
#   46,
#   231,
#   695,
#   8,
#   48,
#   120,
#   616],
#  [115,
#   3,
#   990,
#   58,
#   4348,
#   33,
#   138,
#   183,
#   82,
#   68,
#   282,
#   558,
#   629,
#   58,
#   4,
#   7,
#   303,
#   488,
#   3,
#   5,
#   46,
#   231,
#   695,
#   8,
#   48,
#   120,
#   616],
#  [1826, 346, 50, 68, 140, 7270, 8, 5, 275, 5146, 20, 136],
#  [1826, 7, 346, 89, 5, 275, 6, 6155, 7270, 15, 52, 20, 136],
#  [1826, 52, 346, 50, 68, 2422, 7270, 8, 5, 275, 74, 115, 3, 20, 136],
#  [1826, 346, 50, 190, 140, 7270, 8, 5, 275, 5146, 20, 136],
#  [9, 1826, 346, 50, 68, 140, 7270, 8, 5, 275, 26656, 1326, 20, 5, 136],
#  [1826, 346, 82, 68, 152, 7270, 8, 5, 275, 5146, 128, 136],
#  [44,
#   6,
#   111,
#   396,
#   13947,
#   7,
#   190,
#   416,
#   140,
#   24230,
#   1825,
#   252,
#   139,
#   1007,
#   281,
#   10159,
#   208,
#   1382,
#   4983,
#   8,
#   875,
#   9,
#   5,
#   419,
#   3,
#   20,
#   8,
#   5,
#   404,
#   1382,
#   4983,
#   1230,
#   31],
#  [44,
#   6,
#   111,
#   396,
#   13947,
#   7,
#   190,
#   416,
#   140,
#   71,
#   1825,
#   252,
#   139,
#   1007,
#   281,
#   10159,
#   208,
#   1382,
#   4983,
#   8,
#   875,
#   9,
#   5,
#   419,
#   3,
#   20,
#   8,
#   53,
#   1589,
#   44,
#   1382,
#   4983,
#   1230,
#   31],
#  [44,
#   6,
#   111,
#   396,
#   26657,
#   190,
#   416,
#   140,
#   71,
#   1825,
#   252,
#   139,
#   1007,
#   281,
#   10159,
#   208,
#   231,
#   4983,
#   8,
#   875,
#   9,
#   5,
#   875,
#   9,
#   5,
#   419,
#   3,
#   20,
#   8,
#   5,
#   404,
#   231,
#   4983,
#   1230,
#   31],
#  [44,
#   6,
#   111,
#   396,
#   13947,
#   7,
#   190,
#   140,
#   24230,
#   1825,
#   252,
#   139,
#   1007,
#   281,
#   10159,
#   469,
#   208,
#   68,
#   4983,
#   8,
#   875,
#   839,
#   5,
#   419,
#   3,
#   20,
#   8,
#   5,
#   404,
#   144,
#   1230,
#   31],
#  [44,
#   6,
#   111,
#   833,
#   396,
#   13947,
#   7,
#   190,
#   236,
#   416,
#   28,
#   140,
#   71,
#   4,
#   60,
#   1825,
#   252,
#   139,
#   1,
#   1007,
#   281,
#   3,
#   10159,
#   3,
#   208,
#   1382,
#   4983,
#   8,
#   875,
#   9,
#   5,
#   419,
#   3,
#   1535,
#   20,
#   8,
#   5,
#   163,
#   404,
#   1382,
#   4983,
#   85,
#   1230,
#   31],
#  [44,
#   6,
#   124,
#   396,
#   2354,
#   7,
#   190,
#   416,
#   13947,
#   71,
#   1825,
#   252,
#   32,
#   1007,
#   281,
#   10159,
#   9,
#   1382,
#   4983,
#   8,
#   7271,
#   69,
#   5,
#   419,
#   3,
#   20,
#   31,
#   5,
#   404,
#   27,
#   71,
#   22284],
#  [95, 18789],
#  [10160, 24231],
#  [95, 18789],
#  [95, 18789, 60],
#  [5, 95, 18789],
#  [95, 12],
#  [2,
#   262,
#   15,
#   10,
#   645,
#   2102,
#   7272,
#   491,
#   13,
#   2102,
#   1199,
#   176,
#   946,
#   10,
#   7,
#   1,
#   145,
#   136,
#   503,
#   99,
#   8,
#   1,
#   18,
#   240,
#   41,
#   1152,
#   97,
#   1245,
#   4505,
#   140,
#   100,
#   271,
#   21,
#   1,
#   1153,
#   3,
#   50,
#   2102,
#   181,
#   24,
#   762,
#   1,
#   4505,
#   164,
#   808],
#  [2,
#   262,
#   15,
#   10,
#   1131,
#   3001,
#   7272,
#   491,
#   13,
#   3001,
#   447,
#   176,
#   946,
#   331,
#   1,
#   145,
#   136,
#   183,
#   99,
#   8,
#   1,
#   18,
#   240,
#   41,
#   1152,
#   532,
#   4505,
#   140,
#   100,
#   271,
#   21,
#   1,
#   1153,
#   3,
#   50,
#   3001,
#   181,
#   24,
#   762,
#   164,
#   1,
#   4505],
#  [2,
#   262,
#   15,
#   10,
#   645,
#   2102,
#   7272,
#   491,
#   13,
#   2102,
#   447,
#   176,
#   946,
#   10,
#   7,
#   1,
#   145,
#   136,
#   183,
#   99,
#   8,
#   1,
#   18,
#   240,
#   41,
#   1152,
#   97,
#   1245,
#   4505,
#   140,
#   100,
#   271,
#   21,
#   1,
#   1153,
#   3,
#   50,
#   2102,
#   181,
#   24,
#   762,
#   1,
#   4505,
#   164,
#   808],
#  [2,
#   262,
#   544,
#   10,
#   645,
#   135,
#   495,
#   491,
#   13,
#   2102,
#   1199,
#   176,
#   946,
#   10,
#   7,
#   1,
#   145,
#   136,
#   503,
#   99,
#   8,
#   1,
#   18,
#   240,
#   41,
#   1152,
#   97,
#   1245,
#   4505,
#   140,
#   100,
#   271,
#   21,
#   68,
#   2494,
#   3,
#   50,
#   2102,
#   181,
#   24,
#   762,
#   1,
#   4505,
#   164,
#   808],
#  [2,
#   262,
#   788,
#   15,
#   10,
#   645,
#   2102,
#   7272,
#   491,
#   13,
#   1122,
#   2102,
#   364,
#   80,
#   47,
#   176,
#   946,
#   10,
#   7,
#   1,
#   399,
#   145,
#   868,
#   136,
#   537,
#   2,
#   80,
#   766,
#   99,
#   8,
#   1,
#   18,
#   360,
#   240,
#   41,
#   1152,
#   97,
#   1245,
#   4505,
#   140,
#   100,
#   45,
#   271,
#   21,
#   1,
#   1153,
#   1153,
#   3,
#   5,
#   50,
#   2102,
#   181,
#   24,
#   762,
#   1,
#   4505,
#   164,
#   808],
#  [2,
#   262,
#   15,
#   10,
#   645,
#   1245,
#   7272,
#   491,
#   13,
#   18,
#   181,
#   176,
#   946,
#   15,
#   7,
#   1,
#   77,
#   136,
#   503,
#   574,
#   8,
#   1,
#   681,
#   358,
#   41,
#   1152,
#   97,
#   1245,
#   4505,
#   140,
#   100,
#   1154,
#   21,
#   1,
#   1153,
#   3,
#   50,
#   2102,
#   181,
#   24,
#   762,
#   1,
#   4505,
#   9,
#   808],
#  [13948,
#   360,
#   1085,
#   298,
#   296,
#   88,
#   635,
#   1,
#   140,
#   1900,
#   9487,
#   1850,
#   358,
#   11,
#   1521,
#   380,
#   220,
#   4349,
#   13949,
#   18,
#   2,
#   55,
#   376,
#   160,
#   9,
#   10,
#   1063,
#   3102,
#   3,
#   527],
#  [13948,
#   1085,
#   296,
#   635,
#   1,
#   8383,
#   9487,
#   1850,
#   358,
#   11,
#   1521,
#   220,
#   4349,
#   13949,
#   18,
#   2,
#   55,
#   125,
#   160,
#   9,
#   10,
#   2685,
#   3102,
#   3,
#   527],
#  [26658,
#   1085,
#   298,
#   296,
#   88,
#   635,
#   1,
#   9487,
#   6746,
#   358,
#   11,
#   1124,
#   194,
#   220,
#   4349,
#   18,
#   2,
#   55,
#   125,
#   160,
#   9,
#   10,
#   771,
#   3102,
#   3,
#   527],
#  [13948,
#   360,
#   1085,
#   298,
#   296,
#   139,
#   635,
#   1,
#   140,
#   1900,
#   9487,
#   1850,
#   358,
#   11,
#   1521,
#   380,
#   53,
#   4349,
#   13949,
#   18,
#   2,
#   55,
#   376,
#   160,
#   9,
#   10,
#   1063,
#   3002,
#   3,
#   527],
#  [1563,
#   13948,
#   360,
#   1085,
#   298,
#   296,
#   88,
#   635,
#   1,
#   140,
#   4647,
#   1900,
#   9487,
#   1850,
#   4210,
#   358,
#   6157,
#   11,
#   1521,
#   380,
#   220,
#   4349,
#   13949,
#   338,
#   18,
#   2,
#   55,
#   49,
#   80,
#   47,
#   160,
#   9,
#   10,
#   1063,
#   3102,
#   695,
#   3,
#   527],
#  [13948,
#   360,
#   29,
#   298,
#   296,
#   88,
#   635,
#   1,
#   289,
#   1900,
#   9487,
#   1850,
#   358,
#   39,
#   1521,
#   380,
#   220,
#   642,
#   13949,
#   18,
#   2,
#   575,
#   376,
#   160,
#   13,
#   10,
#   1063,
#   3102,
#   3,
#   527],
#  [882,
#   1,
#   2887,
#   6747,
#   22285,
#   18790,
#   4,
#   13950,
#   13951,
#   1990,
#   595,
#   8,
#   10,
#   593,
#   10161,
#   1590,
#   13952,
#   140,
#   18791,
#   13953,
#   674,
#   1809,
#   4,
#   18792,
#   19,
#   245,
#   13954,
#   4,
#   10162,
#   10163,
#   139],
#  [882,
#   1,
#   779,
#   6747,
#   10164,
#   15,
#   18790,
#   4,
#   13950,
#   13951,
#   6158,
#   8,
#   10,
#   6433,
#   10161,
#   1590,
#   13952,
#   6155,
#   18791,
#   13953,
#   674,
#   1809,
#   4,
#   26659,
#   19,
#   245,
#   13954,
#   4,
#   10162,
#   10163,
#   139],
#  [24232,
#   1,
#   779,
#   6747,
#   6747,
#   6,
#   26660,
#   4,
#   13950,
#   26661,
#   595,
#   8,
#   10,
#   3206,
#   10161,
#   1590,
#   18793,
#   2422,
#   4211,
#   5878,
#   674,
#   4350,
#   1348,
#   19,
#   245,
#   173,
#   4,
#   10162,
#   10163,
#   139],
#  [882,
#   1,
#   2887,
#   6747,
#   22285,
#   18790,
#   4,
#   26662,
#   13951,
#   22,
#   595,
#   8,
#   10,
#   593,
#   10161,
#   1590,
#   13952,
#   140,
#   8894,
#   13953,
#   2790,
#   1809,
#   4,
#   18792,
#   19,
#   245,
#   13954,
#   4,
#   10162,
#   10163,
#   139],
#  [882,
#   64,
#   1,
#   2887,
#   4984,
#   6747,
#   22285,
#   18790,
#   4,
#   13950,
#   13951,
#   45,
#   1990,
#   595,
#   595,
#   8,
#   2169,
#   10,
#   593,
#   10161,
#   4648,
#   1590,
#   937,
#   13952,
#   140,
#   18791,
#   13953,
#   674,
#   1809,
#   8895,
#   4,
#   18792,
#   19,
#   245,
#   13954,
#   2255,
#   4,
#   10162,
#   10163,
#   22286,
#   139],
#  [882,
#   1,
#   2887,
#   5147,
#   5357,
#   26663,
#   4,
#   13950,
#   13951,
#   1111,
#   595,
#   8,
#   111,
#   593,
#   10161,
#   4649,
#   13952,
#   26664,
#   18791,
#   13953,
#   674,
#   10164,
#   4,
#   18792,
#   19,
#   245,
#   26665,
#   4,
#   10162,
#   10163,
#   138],
#  [140, 66, 45, 2, 3320, 5, 3626, 34, 2643, 968, 1500, 179, 1613, 110, 4814],
#  [140, 66, 49, 2, 1614, 5, 3626, 34, 2643, 367, 402, 179, 1030, 110, 4814],
#  [140, 66, 3, 1614, 5, 3626, 34, 2643, 367, 402, 179, 1030, 4814],
#  [140, 66, 200, 2, 3320, 5, 3626, 34, 2643, 968, 1500, 179, 5358, 110, 4814],
#  [140,
#   66,
#   45,
#   4212,
#   2,
#   3320,
#   5,
#   3626,
#   34,
#   2643,
#   26666,
#   47,
#   88,
#   1500,
#   179,
#   608,
#   1613,
#   110,
#   4814],
#  [37, 66, 45, 2, 3320, 192, 3626, 34, 2643, 968, 3813, 179, 1613, 110, 4814],
#  [27, 1, 140, 26, 1162, 438],
#  [27, 1, 140, 26, 203, 4650],
#  [27, 1, 140, 26, 93, 2837],
#  [27, 1, 140, 73, 1162, 438],
#  [1991, 27, 1, 140, 26, 1162, 438],
#  [27, 1, 140, 26, 1162, 336],
#  [248,
#   196,
#   292,
#   140,
#   71,
#   1,
#   975,
#   18,
#   50,
#   7,
#   86,
#   360,
#   27,
#   2228,
#   299,
#   136,
#   4,
#   2,
#   153,
#   509,
#   1035,
#   30,
#   2,
#   1200,
#   3,
#   1600,
#   15,
#   374,
#   13,
#   1,
#   243,
#   1073,
#   27,
#   2,
#   52,
#   208,
#   7,
#   15,
#   59,
#   132,
#   109,
#   19,
#   303,
#   488,
#   3,
#   1,
#   10165,
#   4985,
#   4351],
#  [248,
#   196,
#   64,
#   140,
#   71,
#   1,
#   975,
#   18,
#   7,
#   86,
#   360,
#   27,
#   1366,
#   299,
#   559,
#   4,
#   2,
#   153,
#   1035,
#   30,
#   2,
#   99,
#   3,
#   1600,
#   13,
#   1,
#   243,
#   1073,
#   27,
#   2,
#   52,
#   208,
#   7,
#   15,
#   2,
#   120,
#   132,
#   109,
#   303,
#   488,
#   3,
#   1,
#   10165,
#   8896,
#   4351],
#  [10,
#   374,
#   13,
#   1,
#   243,
#   1073,
#   27,
#   2,
#   52,
#   208,
#   7,
#   15,
#   59,
#   303,
#   488,
#   3,
#   53,
#   18794,
#   8897],
#  [248,
#   196,
#   292,
#   140,
#   71,
#   1,
#   403,
#   18,
#   50,
#   7,
#   86,
#   360,
#   27,
#   2228,
#   299,
#   136,
#   4,
#   2,
#   153,
#   509,
#   1035,
#   30,
#   2,
#   1200,
#   3,
#   1600,
#   1,
#   374,
#   13,
#   3,
#   220,
#   1073,
#   27,
#   2,
#   52,
#   208,
#   7,
#   15,
#   59,
#   132,
#   109,
#   19,
#   303,
#   488,
#   3,
#   124,
#   10165,
#   4985,
#   4351],
#  [248,
#   196,
#   292,
#   140,
#   71,
#   1,
#   975,
#   18,
#   2,
#   50,
#   7,
#   86,
#   360,
#   27,
#   2228,
#   299,
#   136,
#   4,
#   380,
#   2,
#   153,
#   509,
#   1035,
#   109,
#   30,
#   283,
#   2,
#   575,
#   1200,
#   3,
#   1600,
#   15,
#   298,
#   374,
#   13,
#   1,
#   243,
#   859,
#   1073,
#   27,
#   2,
#   52,
#   208,
#   7,
#   15,
#   59,
#   132,
#   203,
#   109,
#   19,
#   488,
#   303,
#   488,
#   3,
#   1,
#   10165,
#   3533,
#   4985,
#   4351],
#  [248,
#   196,
#   292,
#   140,
#   113,
#   1,
#   975,
#   18,
#   50,
#   7,
#   86,
#   360,
#   27,
#   2228,
#   233,
#   136,
#   4,
#   2,
#   153,
#   509,
#   1035,
#   369,
#   2,
#   1200,
#   3,
#   1600,
#   15,
#   374,
#   7,
#   1,
#   243,
#   1073,
#   24,
#   2,
#   52,
#   208,
#   37,
#   285,
#   26667,
#   132,
#   109,
#   19,
#   303,
#   488,
#   3,
#   1,
#   3911,
#   4985,
#   4351],
#  [991, 129, 54, 13955, 5610, 335, 525, 4008, 651],
#  [2, 56, 129, 54, 13955, 5610, 210, 525, 8385, 651],
#  [56, 129, 54, 26668, 5610, 291, 335, 525, 4008, 651],
#  [991, 129, 54, 13955, 5610, 335, 525, 4008, 651],
#  [991, 107, 129, 605, 54, 13955, 5610, 64, 335, 525, 525, 4008, 651],
#  [45, 129, 54, 13955, 60, 41, 146, 4008, 651],
#  [227, 1312, 44, 6, 1, 1536, 348, 13956],
#  [1312, 44, 6, 1, 1536, 3534, 13956],
#  [227, 1312, 44, 6, 1, 386, 2949, 6, 3534],
#  [227, 3, 44, 6, 1, 1536, 348, 13956],
#  [996, 227, 1312, 44, 6, 1, 1536, 348, 13956],
#  [227, 1312, 44, 6, 1, 1536, 1646, 13956],
#  [66, 1, 314, 26, 39, 194, 2495, 444, 249],
#  [66, 1, 314, 26, 39, 249, 194, 2495, 444],
#  [66, 1, 314, 26, 39, 249, 8, 2495, 444],
#  [66, 1, 314, 26, 2049, 194, 2495, 444, 249],
#  [66, 1, 314, 26, 3714, 39, 194, 2495, 444, 695, 249],
#  [8, 1, 314, 26, 39, 194, 2495, 444, 249],
#  [61, 5, 643],
#  [61, 5, 5879],
#  [61, 5, 643],
#  [61, 532, 643],
#  [61, 5, 643],
#  [61, 5, 3912],
#  [554,
#   2,
#   120,
#   991,
#   10,
#   144,
#   89,
#   5148,
#   123,
#   13957,
#   8,
#   377,
#   441,
#   21,
#   1367,
#   132,
#   140,
#   30,
#   4,
#   1,
#   2170,
#   7,
#   8386],
#  [554,
#   59,
#   991,
#   10,
#   144,
#   89,
#   5148,
#   123,
#   13957,
#   8,
#   232,
#   1191,
#   21,
#   5,
#   1367,
#   132,
#   140,
#   30,
#   4,
#   1,
#   2170,
#   7,
#   8386],
#  [554,
#   2,
#   120,
#   991,
#   10,
#   144,
#   89,
#   5148,
#   123,
#   26669,
#   8,
#   377,
#   441,
#   21,
#   139,
#   132,
#   140,
#   30,
#   4,
#   1,
#   2170,
#   7,
#   8386],
#  [554,
#   2,
#   120,
#   991,
#   10,
#   144,
#   539,
#   259,
#   123,
#   13957,
#   8,
#   377,
#   441,
#   21,
#   1367,
#   132,
#   140,
#   30,
#   4,
#   1,
#   2170,
#   7,
#   282],
#  [554,
#   1320,
#   2,
#   120,
#   991,
#   10,
#   144,
#   23,
#   89,
#   5148,
#   123,
#   13957,
#   4,
#   8,
#   1086,
#   377,
#   441,
#   124,
#   21,
#   1367,
#   2,
#   132,
#   140,
#   30,
#   4,
#   1,
#   2170,
#   7,
#   8386],
#  [554,
#   2,
#   120,
#   991,
#   10,
#   144,
#   89,
#   5148,
#   4,
#   2050,
#   8,
#   377,
#   441,
#   21,
#   1367,
#   132,
#   46,
#   2578,
#   4,
#   1,
#   2170,
#   7,
#   8386],
#  [23, 2838, 27, 6, 14, 243, 83, 3, 128, 1284, 9, 140, 71],
#  [23, 4506, 27, 14, 243, 83, 3, 128, 1087, 9, 140, 71],
#  [23, 1218, 27, 14, 243, 83, 3, 128, 1087, 9, 140, 71],
#  [23, 2838, 27, 6, 14, 243, 83, 52, 128, 1284, 9, 140, 71],
#  [23, 2838, 27, 243, 6, 14, 14, 243, 83, 3, 128, 1284, 9, 460, 140, 71],
#  [23, 2838, 27, 6, 27, 243, 83, 8, 128, 1284, 9, 140, 71],
#  [249,
#   991,
#   5359,
#   1099,
#   61,
#   5,
#   4507,
#   18,
#   1207,
#   749,
#   159,
#   140,
#   4,
#   7814,
#   18,
#   443,
#   296,
#   40],
#  [2,
#   56,
#   5359,
#   1099,
#   61,
#   5,
#   4507,
#   18,
#   26670,
#   6,
#   159,
#   140,
#   4,
#   7814,
#   18,
#   443,
#   296,
#   40],
#  [1207, 749, 159, 140, 4, 7814, 18, 443, 296, 40],
#  [249,
#   991,
#   5359,
#   1099,
#   61,
#   5,
#   136,
#   18,
#   1207,
#   749,
#   159,
#   140,
#   4,
#   91,
#   18,
#   443,
#   296,
#   40],
#  [249,
#   144,
#   991,
#   1,
#   5359,
#   1099,
#   61,
#   7,
#   5,
#   4507,
#   18,
#   1207,
#   749,
#   159,
#   140,
#   4,
#   854,
#   7814,
#   18,
#   443,
#   1238,
#   296,
#   31,
#   40],
#  [249,
#   196,
#   5359,
#   1099,
#   61,
#   5,
#   4507,
#   18,
#   1207,
#   749,
#   1219,
#   140,
#   1537,
#   7814,
#   18,
#   443,
#   89,
#   40],
#  [3535, 4, 140, 404, 3, 1, 636, 643, 1923, 21, 1, 95, 8],
#  [3535, 4, 140, 404, 3, 1, 636, 643, 1923, 21, 1, 95, 8],
#  [3535, 4, 140, 404, 3, 1, 636, 643, 1923, 21, 1, 95, 8],
#  [3535, 4, 140, 404, 3, 1, 3715, 643, 1923, 21, 1, 95, 8],
#  [3535, 26671, 4, 243, 140, 26, 404, 3, 1, 636, 643, 1923, 21, 1, 95, 8],
#  [3535, 4, 140, 404, 114, 34, 636, 643, 1923, 21, 1, 95, 8],
#  [2423, 7, 1, 77, 1246, 140],
#  [2423, 7, 1, 77, 5611, 140],
#  [2423, 7, 1, 77, 295, 140],
#  [2423, 42, 1, 77, 1246, 140],
#  [2423, 1679, 7, 2686, 1, 77, 1246, 140],
#  [2423, 7, 1, 77, 1246, 1],
#  [9,
#   68,
#   451,
#   14,
#   1356,
#   49,
#   448,
#   140,
#   71,
#   284,
#   3627,
#   4,
#   7815,
#   27,
#   13,
#   521,
#   1564,
#   24,
#   1,
#   844,
#   2,
#   88,
#   354,
#   3,
#   88,
#   523,
#   214,
#   14,
#   608,
#   886,
#   1092],
#  [9,
#   68,
#   451,
#   14,
#   1356,
#   49,
#   448,
#   140,
#   71,
#   284,
#   3627,
#   4,
#   7815,
#   28,
#   521,
#   1564,
#   24,
#   1,
#   844,
#   2,
#   88,
#   354,
#   3,
#   345,
#   214,
#   14,
#   608,
#   886,
#   1092],
#  [9,
#   68,
#   451,
#   14,
#   1356,
#   49,
#   448,
#   140,
#   71,
#   284,
#   3627,
#   4,
#   7815,
#   28,
#   521,
#   1564,
#   24,
#   1,
#   844,
#   2,
#   88,
#   354,
#   3,
#   448,
#   214,
#   14,
#   368,
#   886,
#   3375,
#   221],
#  [9,
#   68,
#   451,
#   14,
#   3207,
#   49,
#   448,
#   140,
#   71,
#   284,
#   3627,
#   871,
#   7815,
#   27,
#   13,
#   521,
#   1564,
#   51,
#   1,
#   844,
#   2,
#   88,
#   354,
#   3,
#   88,
#   523,
#   214,
#   124,
#   608,
#   886,
#   1092],
#  [9,
#   68,
#   451,
#   14,
#   1356,
#   49,
#   1658,
#   448,
#   140,
#   4348,
#   71,
#   3001,
#   284,
#   3627,
#   4,
#   7815,
#   27,
#   530,
#   13,
#   521,
#   1564,
#   5,
#   24,
#   5,
#   1,
#   844,
#   2,
#   88,
#   2734,
#   354,
#   3,
#   88,
#   523,
#   214,
#   3,
#   14,
#   744,
#   608,
#   886,
#   1092],
#  [9,
#   68,
#   451,
#   14,
#   1183,
#   49,
#   2540,
#   1522,
#   71,
#   284,
#   3627,
#   1267,
#   3627,
#   27,
#   13,
#   521,
#   2384,
#   24,
#   1,
#   844,
#   2,
#   88,
#   354,
#   3,
#   88,
#   523,
#   32,
#   14,
#   608,
#   886,
#   1092],
#  [2051,
#   13,
#   231,
#   684,
#   138,
#   89,
#   68,
#   62,
#   6,
#   1,
#   140,
#   6159,
#   18795,
#   31,
#   3,
#   14,
#   54,
#   5612,
#   2,
#   217,
#   227,
#   2687,
#   144,
#   1901,
#   14,
#   929,
#   221,
#   3,
#   13958,
#   3,
#   72,
#   43,
#   11,
#   327,
#   192,
#   1924,
#   3,
#   66,
#   189,
#   14,
#   231,
#   1331,
#   13,
#   14,
#   947,
#   401,
#   614,
#   134,
#   108,
#   18796],
#  [345,
#   499,
#   10,
#   506,
#   59,
#   78,
#   89,
#   68,
#   6,
#   1,
#   140,
#   6159,
#   4,
#   26672,
#   3,
#   14,
#   54,
#   5612,
#   183,
#   217,
#   227,
#   2687,
#   59,
#   144,
#   13959,
#   14,
#   929,
#   3,
#   13958,
#   3,
#   72,
#   43,
#   11,
#   327,
#   5,
#   1924,
#   66,
#   189,
#   14,
#   231,
#   1331,
#   13,
#   14,
#   336,
#   401,
#   614,
#   134,
#   108,
#   18796],
#  [3814,
#   231,
#   684,
#   138,
#   89,
#   68,
#   62,
#   6,
#   1,
#   140,
#   974,
#   18795,
#   31,
#   3,
#   14,
#   54,
#   5612,
#   2,
#   217,
#   227,
#   2687,
#   144,
#   2424,
#   14,
#   929,
#   221,
#   3,
#   13958,
#   3,
#   72,
#   43,
#   11,
#   7,
#   192,
#   1924,
#   3,
#   66,
#   189,
#   14,
#   231,
#   1331,
#   13,
#   14,
#   22287,
#   401,
#   614],
#  [2051,
#   13,
#   231,
#   684,
#   138,
#   89,
#   68,
#   62,
#   6,
#   1,
#   140,
#   6159,
#   18795,
#   31,
#   3,
#   14,
#   54,
#   5612,
#   2,
#   217,
#   227,
#   2687,
#   144,
#   1901,
#   14,
#   929,
#   221,
#   3,
#   13958,
#   3,
#   72,
#   43,
#   11,
#   327,
#   192,
#   1924,
#   3,
#   66,
#   189,
#   14,
#   231,
#   1331,
#   13,
#   14,
#   947,
#   401,
#   614,
#   134,
#   108,
#   18796],
#  [1,
#   2051,
#   13,
#   231,
#   684,
#   138,
#   89,
#   68,
#   62,
#   6,
#   1,
#   140,
#   6159,
#   18795,
#   31,
#   3,
#   14,
#   54,
#   5612,
#   2,
#   217,
#   227,
#   2687,
#   144,
#   1901,
#   14,
#   929,
#   221,
#   3,
#   13958,
#   3,
#   72,
#   43,
#   11,
#   327,
#   192,
#   1924,
#   3,
#   66,
#   189,
#   14,
#   231,
#   1331,
#   13,
#   14,
#   947,
#   401,
#   614,
#   134,
#   108,
#   18796],
#  [70],
#  [2, 1285, 15, 6160, 3913, 4, 2, 1615, 9, 14, 258],
#  [2, 714, 194, 1, 26673, 4, 1615, 9, 14, 258],
#  [2, 1285, 15, 6160, 3913, 4, 2, 1615, 9, 14, 258],
#  [2, 1285, 15, 6160, 3913, 4, 206, 1615, 9, 14, 258],
#  [2, 154, 1285, 8, 15, 6160, 3913, 4, 2, 1615, 9, 14, 258],
#  [2, 1285, 15, 6160, 3913, 4, 2, 1615, 9, 5, 258],
#  [95, 11, 35, 36, 16, 13960],
#  [95, 11, 35, 36, 16, 13960],
#  [95, 11, 35, 730, 435, 13960],
#  [95, 11, 35, 36, 16, 13960],
#  [180, 95, 11, 35, 36, 16, 13960],
#  [2],
#  [140, 33, 7, 19, 46, 622],
#  [140, 33, 7, 19, 46, 622],
#  [140, 33, 7, 19, 46, 622],
#  [140, 33, 7, 37, 46, 622],
#  [140, 33, 7, 147, 19, 46, 622],
#  [140, 33, 7, 19, 53, 622],
#  [266, 33, 2, 18797, 1, 1757, 4, 37, 396, 140, 71],
#  [266, 33, 2, 26674, 1, 1757, 4, 37, 396, 140, 71],
#  [266, 33, 2, 4815, 1, 1757, 4, 37, 396, 140, 71],
#  [266, 33, 2, 18797, 1, 1757, 90, 37, 396, 140, 71],
#  [266, 33, 2, 18797, 13, 1, 814, 1757, 2496, 4, 37, 396, 140, 71],
#  [266, 33, 2, 18797, 1, 1757, 39, 37, 396, 140, 71],
#  [140,
#   232,
#   496,
#   132,
#   450,
#   17,
#   10166,
#   787,
#   5149,
#   1332,
#   1901,
#   623,
#   295,
#   137,
#   1579,
#   2102,
#   2385,
#   66,
#   7,
#   10,
#   898,
#   17,
#   5,
#   8387,
#   1246,
#   7272,
#   13,
#   2,
#   1268,
#   59,
#   539,
#   62,
#   13961,
#   4,
#   4213,
#   137,
#   377,
#   13,
#   1773,
#   770],
#  [140,
#   232,
#   496,
#   132,
#   450,
#   17,
#   10166,
#   787,
#   5149,
#   1332,
#   2150,
#   623,
#   137,
#   1579,
#   3001,
#   2385,
#   66,
#   7,
#   10,
#   898,
#   57,
#   5,
#   8387,
#   1246,
#   7272,
#   7,
#   13,
#   2,
#   1268,
#   2,
#   72,
#   62,
#   13961,
#   4,
#   4213,
#   137,
#   377,
#   13,
#   1773,
#   770],
#  [140,
#   232,
#   496,
#   132,
#   450,
#   17,
#   1,
#   10166,
#   787,
#   1601,
#   1332,
#   2150,
#   623,
#   137,
#   1,
#   1579,
#   2385,
#   6,
#   2102,
#   40,
#   898,
#   17,
#   1,
#   1628,
#   7272],
#  [140,
#   232,
#   496,
#   597,
#   450,
#   17,
#   10166,
#   787,
#   5149,
#   1332,
#   2386,
#   623,
#   295,
#   137,
#   1392,
#   2102,
#   2385,
#   66,
#   7,
#   10,
#   898,
#   17,
#   5,
#   8387,
#   1246,
#   7272,
#   13,
#   67,
#   1268,
#   59,
#   1629,
#   62,
#   13961,
#   4,
#   4213,
#   137,
#   377,
#   13,
#   1773,
#   770],
#  [33,
#   140,
#   232,
#   496,
#   132,
#   450,
#   17,
#   10166,
#   787,
#   2644,
#   5149,
#   1332,
#   1901,
#   496,
#   623,
#   295,
#   137,
#   1579,
#   2102,
#   2385,
#   71,
#   66,
#   883,
#   7,
#   10,
#   898,
#   17,
#   5,
#   8387,
#   1246,
#   7272,
#   212,
#   13,
#   85,
#   2,
#   1268,
#   59,
#   206,
#   539,
#   62,
#   13961,
#   4,
#   4213,
#   37,
#   137,
#   377,
#   13,
#   1773,
#   770],
#  [140,
#   232,
#   496,
#   132,
#   450,
#   17,
#   10166,
#   787,
#   5149,
#   1332,
#   1901,
#   623,
#   617,
#   32,
#   1579,
#   6748,
#   139,
#   66,
#   7,
#   10,
#   872,
#   17,
#   34,
#   8387,
#   1246,
#   7272,
#   13,
#   60,
#   1268,
#   59,
#   539,
#   62,
#   13961,
#   123,
#   4213,
#   137,
#   377,
#   13,
#   1773,
#   770],
#  [59,
#   8,
#   10,
#   13962,
#   152,
#   10167,
#   4214,
#   13963,
#   1057,
#   129,
#   2735,
#   6,
#   111,
#   789,
#   8898,
#   24233,
#   544,
#   10,
#   7,
#   7816,
#   9488,
#   4,
#   1,
#   940,
#   6,
#   1,
#   140,
#   8,
#   264,
#   24234,
#   10168,
#   18798,
#   104,
#   13,
#   1305,
#   1774,
#   114,
#   2229,
#   8388,
#   17,
#   18799,
#   18800,
#   8389,
#   1254],
#  [59,
#   8,
#   10,
#   13962,
#   152,
#   10167,
#   4214,
#   26675,
#   1057,
#   129,
#   2735,
#   6,
#   111,
#   789,
#   85,
#   24233,
#   422,
#   10,
#   7,
#   4215,
#   9488,
#   4,
#   1,
#   940,
#   6,
#   1,
#   2422,
#   1155,
#   8,
#   264,
#   33,
#   26676,
#   10168,
#   8390,
#   104,
#   13,
#   1305,
#   3914,
#   114,
#   2229,
#   8388,
#   17,
#   18799,
#   18800,
#   8389,
#   361,
#   1,
#   1254],
#  [2,
#   120,
#   8,
#   10,
#   152,
#   64,
#   13962,
#   10167,
#   4214,
#   13963,
#   4651,
#   31,
#   129,
#   2735,
#   6,
#   111,
#   789],
#  [59,
#   8,
#   10,
#   13962,
#   152,
#   2230,
#   13963,
#   1057,
#   129,
#   4112,
#   6,
#   15,
#   789,
#   8898,
#   10167,
#   4214,
#   422,
#   10,
#   7,
#   7816,
#   9488,
#   4,
#   1,
#   940,
#   6,
#   1,
#   140,
#   8,
#   264,
#   24234,
#   10168,
#   18798,
#   104,
#   13,
#   1305,
#   1774,
#   6,
#   9489,
#   8388,
#   17,
#   18799,
#   18800,
#   32,
#   1254],
#  [59,
#   8,
#   417,
#   10,
#   608,
#   13962,
#   152,
#   10167,
#   4214,
#   13963,
#   1057,
#   129,
#   2735,
#   6,
#   111,
#   789,
#   1,
#   60,
#   277,
#   544,
#   10,
#   7,
#   7816,
#   194,
#   9488,
#   4,
#   1,
#   940,
#   859,
#   6,
#   1,
#   140,
#   8,
#   264,
#   60,
#   10168,
#   18798,
#   104,
#   13,
#   1305,
#   1774,
#   114,
#   2229,
#   8388,
#   3915,
#   17,
#   18799,
#   1148,
#   18800,
#   123,
#   8389,
#   1254],
#  [59,
#   8,
#   10,
#   18801,
#   152,
#   6749,
#   13963,
#   1057,
#   31,
#   2735,
#   6,
#   111,
#   789,
#   6749,
#   544,
#   10,
#   7,
#   637,
#   9488,
#   4,
#   1,
#   940,
#   6,
#   1,
#   140,
#   8,
#   264,
#   26677,
#   10168,
#   18798,
#   1602,
#   13,
#   1305,
#   1774,
#   114,
#   2229,
#   8388,
#   17,
#   10169,
#   24235,
#   361,
#   111],
#  [2,
#   82,
#   3,
#   50,
#   140,
#   33,
#   17,
#   1,
#   608,
#   18802,
#   390,
#   11,
#   29,
#   136,
#   4,
#   3628,
#   1,
#   1,
#   1647,
#   99,
#   3,
#   398,
#   3103],
#  [2,
#   29,
#   2281,
#   3,
#   50,
#   140,
#   33,
#   390,
#   17,
#   27,
#   1,
#   26678,
#   11,
#   29,
#   559,
#   4,
#   3628,
#   1,
#   1647,
#   99,
#   3,
#   398,
#   3103],
#  [2,
#   99,
#   3,
#   50,
#   140,
#   33,
#   17,
#   27,
#   1,
#   26679,
#   390,
#   11,
#   29,
#   136,
#   4,
#   3628,
#   1,
#   1647,
#   99,
#   3,
#   398,
#   3103],
#  [2,
#   82,
#   3,
#   411,
#   140,
#   33,
#   17,
#   1,
#   608,
#   18802,
#   390,
#   11,
#   29,
#   136,
#   3628,
#   1,
#   1,
#   1647,
#   99,
#   244,
#   398,
#   3103],
#  [19,
#   2,
#   82,
#   3,
#   50,
#   140,
#   365,
#   33,
#   17,
#   1,
#   241,
#   608,
#   18802,
#   390,
#   11,
#   29,
#   55,
#   136,
#   4,
#   3628,
#   1,
#   1,
#   1,
#   1647,
#   248,
#   99,
#   3,
#   398,
#   3103],
#  [2,
#   82,
#   3,
#   50,
#   2541,
#   33,
#   17,
#   179,
#   608,
#   18802,
#   390,
#   11,
#   29,
#   136,
#   581,
#   3628,
#   1,
#   191,
#   1647,
#   99,
#   3,
#   398,
#   3103],
#  [10,
#   7,
#   1063,
#   2,
#   38,
#   15,
#   2950,
#   3815,
#   11,
#   29,
#   623,
#   137,
#   1580,
#   470,
#   3,
#   5,
#   457,
#   3321],
#  [10, 7, 2685, 2, 38, 15, 11, 29, 623, 2950, 137, 1580, 470, 3, 5, 457, 3321],
#  [10,
#   7,
#   771,
#   2,
#   1255,
#   15,
#   1,
#   2950,
#   1124,
#   31,
#   3,
#   20,
#   1579,
#   137,
#   1580,
#   92,
#   6,
#   1,
#   457,
#   3321],
#  [10,
#   7,
#   1063,
#   2,
#   38,
#   15,
#   2950,
#   3815,
#   11,
#   99,
#   623,
#   137,
#   1580,
#   470,
#   3,
#   5,
#   3629,
#   3321],
#  [10,
#   7,
#   1063,
#   2,
#   38,
#   15,
#   2950,
#   3815,
#   11,
#   55,
#   29,
#   623,
#   137,
#   1580,
#   131,
#   470,
#   3,
#   106,
#   5,
#   457,
#   1659,
#   3321],
#  [10,
#   7,
#   1063,
#   2,
#   38,
#   15,
#   2950,
#   3815,
#   11,
#   29,
#   623,
#   436,
#   1580,
#   7817,
#   3,
#   5,
#   457,
#   352],
#  [140, 71, 7, 46, 19, 400, 24, 140, 33, 52, 209, 20, 1, 2126],
#  [140, 71, 7, 46, 19, 400, 24, 140, 33, 52, 209, 20, 1, 321],
#  [140, 71, 7, 46, 19, 400, 24, 140, 33, 52, 209, 20, 1, 2126],
#  [140, 71, 7, 46, 19, 400, 24, 140, 33, 25, 209, 20, 1, 2126],
#  [140, 71, 7, 46, 19, 400, 24, 140, 33, 1383, 52, 209, 346, 20, 1, 2126],
#  [60, 71, 7, 46, 19, 400, 24, 3147, 33, 52, 209, 20, 1, 2126],
#  [248, 82, 375, 3, 695, 140, 71, 10, 592, 4, 2, 56, 11, 249, 19, 189, 217],
#  [248, 2, 1775, 3, 345, 140, 71, 10, 592, 4, 2, 56, 11, 249, 19, 189, 294],
#  [248, 82, 3, 1, 523, 6, 140, 71, 10, 592, 4, 59, 249, 1067, 11, 19, 189, 294],
#  [248, 82, 375, 3, 695, 140, 71, 10, 592, 4, 2, 633, 11, 249, 19, 189, 633],
#  [248,
#   82,
#   375,
#   3,
#   1535,
#   695,
#   140,
#   71,
#   10,
#   368,
#   592,
#   4,
#   2,
#   56,
#   11,
#   115,
#   249,
#   19,
#   189,
#   12,
#   217],
#  [248, 82, 375, 3, 695, 140, 33, 10, 592, 4, 2, 1124, 11, 123, 19, 245, 217],
#  [13964, 3322, 307, 307],
#  [13964, 3322, 307, 307, 307, 307],
#  [26680],
#  [13964, 3322, 64, 307],
#  [13964, 297, 3322, 290, 307, 307],
#  [13964, 3322, 4, 307],
#  [61,
#   5,
#   300,
#   2,
#   99,
#   18803,
#   6,
#   136,
#   89,
#   140,
#   33,
#   734,
#   174,
#   3463,
#   4,
#   3463,
#   1269,
#   1,
#   398,
#   114,
#   1,
#   231,
#   39,
#   4216,
#   10170,
#   61,
#   5,
#   173,
#   1382,
#   17,
#   386,
#   850,
#   2542,
#   271,
#   252,
#   5,
#   562,
#   43,
#   12,
#   126,
#   249,
#   45,
#   3816],
#  [61,
#   5,
#   300,
#   2,
#   99,
#   2579,
#   6,
#   136,
#   89,
#   140,
#   33,
#   39,
#   26,
#   174,
#   3463,
#   4,
#   3463,
#   3,
#   1,
#   398,
#   114,
#   1,
#   231,
#   39,
#   22,
#   4216,
#   10170,
#   61,
#   53,
#   173,
#   1382,
#   17,
#   386,
#   3536,
#   271,
#   11,
#   5,
#   562,
#   58,
#   43,
#   12,
#   759,
#   294,
#   11,
#   380,
#   46,
#   300],
#  [61,
#   5,
#   300,
#   2,
#   99,
#   136,
#   89,
#   140,
#   33,
#   734,
#   174,
#   3463,
#   4,
#   3463,
#   3,
#   1,
#   398,
#   114,
#   1,
#   231,
#   39,
#   7273,
#   292,
#   10170,
#   61,
#   53,
#   173,
#   1682,
#   17,
#   386,
#   834,
#   6,
#   850,
#   362,
#   252,
#   26681,
#   43,
#   12,
#   759,
#   249,
#   46,
#   300],
#  [61,
#   5,
#   300,
#   2,
#   99,
#   18803,
#   6,
#   136,
#   89,
#   140,
#   33,
#   734,
#   174,
#   3463,
#   4,
#   3463,
#   1269,
#   10,
#   398,
#   292,
#   1,
#   231,
#   39,
#   4216,
#   10170,
#   61,
#   5,
#   173,
#   1382,
#   9,
#   386,
#   850,
#   2542,
#   271,
#   11,
#   5,
#   562,
#   43,
#   12,
#   126,
#   249,
#   45,
#   60,
#   3816],
#  [24,
#   61,
#   5,
#   300,
#   2,
#   99,
#   18803,
#   6,
#   136,
#   89,
#   140,
#   33,
#   2048,
#   630,
#   174,
#   192,
#   3463,
#   4,
#   3463,
#   23,
#   1269,
#   1,
#   398,
#   114,
#   1,
#   231,
#   39,
#   4216,
#   10170,
#   5,
#   61,
#   1480,
#   5,
#   173,
#   1382,
#   17,
#   386,
#   850,
#   2542,
#   271,
#   252,
#   9,
#   5,
#   562,
#   43,
#   12,
#   49,
#   126,
#   249,
#   84,
#   45,
#   3816],
#  [6,
#   5,
#   300,
#   2,
#   23,
#   18803,
#   8,
#   136,
#   89,
#   140,
#   33,
#   734,
#   174,
#   3463,
#   4,
#   3463,
#   1269,
#   10,
#   398,
#   114,
#   1,
#   231,
#   29,
#   4216,
#   10170,
#   61,
#   5,
#   296,
#   1382,
#   17,
#   386,
#   850,
#   2542,
#   271,
#   253,
#   5,
#   562,
#   290,
#   39,
#   126,
#   249,
#   19,
#   3816],
#  [98,
#   321,
#   83,
#   6,
#   27,
#   63,
#   161,
#   10171,
#   4,
#   2791,
#   5360,
#   85,
#   1297,
#   33,
#   71,
#   125,
#   969,
#   33,
#   3054,
#   186,
#   71,
#   2425,
#   2736,
#   33,
#   98,
#   305,
#   2645,
#   7274,
#   27,
#   1430,
#   10,
#   29,
#   346,
#   1,
#   121,
#   18,
#   2,
#   147,
#   196,
#   13965,
#   5880,
#   13966,
#   4009,
#   18804,
#   22288,
#   2301,
#   72,
#   2497],
#  [98,
#   321,
#   83,
#   6,
#   27,
#   63,
#   161,
#   10171,
#   4,
#   2791,
#   5360,
#   85,
#   1297,
#   33,
#   71,
#   2,
#   125,
#   2606,
#   33,
#   3054,
#   186,
#   71,
#   2425,
#   2736,
#   33,
#   98,
#   305,
#   2645,
#   7274,
#   27,
#   1430,
#   10,
#   29,
#   346,
#   1,
#   121,
#   18,
#   2,
#   147,
#   196,
#   13965,
#   5880,
#   13966,
#   4009,
#   18804,
#   22288,
#   660,
#   72,
#   2497],
#  [98, 321, 83, 6, 27, 63, 161, 3, 10171, 4, 2791, 26682],
#  [98,
#   321,
#   83,
#   6,
#   27,
#   63,
#   161,
#   2645,
#   4,
#   10171,
#   85,
#   1297,
#   33,
#   71,
#   125,
#   969,
#   33,
#   3054,
#   186,
#   71,
#   2425,
#   4816,
#   33,
#   98,
#   1,
#   2645,
#   7274,
#   27,
#   1430,
#   10,
#   346,
#   2737,
#   1,
#   121,
#   18,
#   2,
#   121,
#   196,
#   2791,
#   5360,
#   13965,
#   5880,
#   13966,
#   4009,
#   18804,
#   2301,
#   72,
#   90],
#  [98,
#   14,
#   321,
#   83,
#   6,
#   27,
#   63,
#   161,
#   10171,
#   4,
#   2791,
#   5360,
#   85,
#   1297,
#   1736,
#   33,
#   268,
#   71,
#   125,
#   88,
#   969,
#   33,
#   33,
#   54,
#   3054,
#   186,
#   71,
#   2425,
#   2736,
#   33,
#   98,
#   305,
#   2645,
#   7274,
#   27,
#   1430,
#   10,
#   29,
#   346,
#   1,
#   121,
#   18,
#   2,
#   147,
#   88,
#   196,
#   13965,
#   5880,
#   13966,
#   4009,
#   18804,
#   22288,
#   43,
#   362,
#   80,
#   117,
#   55,
#   72,
#   2497],
#  [111,
#   321,
#   83,
#   6,
#   27,
#   63,
#   161,
#   10171,
#   245,
#   921,
#   85,
#   1297,
#   33,
#   71,
#   125,
#   1045,
#   33,
#   3054,
#   3003,
#   71,
#   2425,
#   2736,
#   33,
#   98,
#   305,
#   2645,
#   7274,
#   27,
#   1430,
#   10,
#   29,
#   329,
#   1,
#   121,
#   18,
#   21,
#   147,
#   196,
#   2791,
#   5360,
#   13965,
#   5880,
#   13966,
#   313,
#   67,
#   72,
#   48],
#  [3630, 397, 667, 13, 772, 9, 1, 398, 2463, 7, 70, 204, 287, 1058, 140, 946],
#  [3630,
#   17,
#   667,
#   13,
#   772,
#   9,
#   1,
#   398,
#   2463,
#   7,
#   1,
#   451,
#   70,
#   2,
#   52,
#   652,
#   140,
#   946],
#  [3630, 397, 667, 13, 772, 9, 1, 398, 2463, 7, 70, 59, 287, 1058, 140, 946],
#  [3630,
#   397,
#   667,
#   64,
#   772,
#   9,
#   1,
#   398,
#   2463,
#   2839,
#   70,
#   204,
#   287,
#   1058,
#   140,
#   946],
#  [3630,
#   397,
#   667,
#   13,
#   772,
#   9,
#   1850,
#   1,
#   398,
#   2463,
#   11,
#   7,
#   346,
#   70,
#   2,
#   550,
#   80,
#   226,
#   287,
#   1058,
#   140,
#   946],
#  [3630, 297, 667, 13, 772, 9, 1, 398, 2463, 1093, 70, 204, 287, 167, 140, 946],
#  [18805, 59, 206, 19, 907, 9, 10, 653],
#  [26683, 59, 55, 19, 24236, 58, 9, 10, 653],
#  [26684, 59, 206, 19, 907, 9, 10, 653],
#  [18805, 59, 530, 19, 907, 9, 10, 653],
#  [18805, 57, 59, 25, 206, 19, 907, 9, 27, 10, 328, 653],
#  [18805, 59, 206, 19, 907, 9, 15, 330],
#  [735, 27, 317, 83, 26, 822, 10, 140, 7, 1, 77, 6, 124, 634],
#  [735, 27, 129, 83, 26, 983, 10, 2422, 1155, 7, 1, 77, 6, 124, 634],
#  [1827, 27, 6, 129, 83, 26, 46, 10, 166, 4, 26, 1, 77, 6, 110, 634],
#  [735, 27, 317, 83, 26, 822, 10, 140, 7, 346, 77, 6, 124, 634],
#  [735, 27, 317, 83, 26, 822, 10, 7, 140, 7, 1, 77, 2792, 6, 124, 634],
#  [172, 27, 317, 83, 26, 822, 10, 140, 7, 1, 77, 6, 124, 46],
#  [747,
#   845,
#   9,
#   3631,
#   140,
#   71,
#   9,
#   261,
#   4,
#   62,
#   86,
#   18,
#   1406,
#   418,
#   91,
#   44,
#   636,
#   8899,
#   75,
#   747,
#   24237,
#   81,
#   47,
#   75,
#   18806],
#  [747,
#   845,
#   9,
#   3631,
#   140,
#   71,
#   9,
#   261,
#   4,
#   243,
#   86,
#   83,
#   418,
#   91,
#   44,
#   636,
#   8899,
#   75,
#   747,
#   845,
#   81,
#   47,
#   75,
#   18806],
#  [747,
#   845,
#   9,
#   3631,
#   140,
#   71,
#   9,
#   261,
#   4,
#   62,
#   86,
#   18,
#   1406,
#   418,
#   91,
#   44,
#   4508,
#   24238,
#   747,
#   845],
#  [747,
#   845,
#   25,
#   3631,
#   140,
#   9,
#   9,
#   261,
#   27,
#   62,
#   86,
#   18,
#   2151,
#   418,
#   91,
#   44,
#   636,
#   8899,
#   75,
#   747,
#   24237,
#   81,
#   47,
#   75,
#   18806],
#  [747,
#   845,
#   790,
#   9,
#   3631,
#   140,
#   71,
#   9,
#   261,
#   1341,
#   4,
#   62,
#   86,
#   1481,
#   18,
#   726,
#   1406,
#   418,
#   91,
#   44,
#   1481,
#   636,
#   144,
#   8899,
#   72,
#   75,
#   416,
#   747,
#   845,
#   5613,
#   141,
#   81,
#   47,
#   75,
#   18806],
#  [747,
#   845,
#   9,
#   3631,
#   140,
#   254,
#   9,
#   261,
#   4,
#   62,
#   86,
#   46,
#   1406,
#   418,
#   22289,
#   3916,
#   636,
#   37,
#   75,
#   747,
#   845,
#   28],
#  [1, 212, 44, 7, 140, 1, 1922, 1327, 432, 686],
#  [212, 7, 140, 1, 1922, 1327, 12, 26, 686],
#  [212, 58, 7, 140, 1, 1922, 13967],
#  [1, 212, 44, 7, 140, 77, 1922, 1327, 432, 686],
#  [1, 212, 958, 44, 7, 140, 9, 1, 748, 1922, 1327, 432, 686],
#  [1, 512, 44, 7, 140, 1, 1922, 1327, 26685, 686],
#  [2,
#   6434,
#   3323,
#   3632,
#   4,
#   1,
#   736,
#   4986,
#   7,
#   5,
#   1012,
#   398,
#   3,
#   1,
#   140,
#   71,
#   974,
#   461,
#   15,
#   10172,
#   13,
#   5,
#   543,
#   321,
#   540,
#   4,
#   1191,
#   308,
#   7818,
#   222,
#   13968,
#   13,
#   68,
#   132,
#   224,
#   1758,
#   6,
#   26686,
#   540,
#   4,
#   4987,
#   629,
#   2542,
#   222,
#   4988,
#   17],
#  [3323,
#   3632,
#   4,
#   1,
#   736,
#   4986,
#   7,
#   5,
#   1012,
#   6435,
#   3,
#   1,
#   140,
#   71,
#   974,
#   461,
#   237,
#   10172,
#   13,
#   5,
#   543,
#   321,
#   540,
#   4,
#   2327,
#   308,
#   7818,
#   222,
#   5,
#   6435,
#   13,
#   68,
#   132,
#   224,
#   603,
#   6,
#   1,
#   540,
#   6,
#   284,
#   4,
#   4987,
#   629,
#   2542,
#   17,
#   237,
#   222,
#   4988],
#  [3323,
#   4,
#   26687,
#   26688,
#   7,
#   1,
#   467,
#   6435,
#   3,
#   1,
#   140,
#   71,
#   461,
#   237,
#   10172,
#   13,
#   1,
#   579,
#   321,
#   540,
#   4,
#   1191,
#   1,
#   222,
#   1,
#   1482,
#   3,
#   818,
#   9,
#   5,
#   308,
#   63,
#   68,
#   132,
#   970,
#   1758,
#   26689,
#   540,
#   4,
#   1,
#   4987,
#   6161,
#   17,
#   237,
#   1,
#   222,
#   4988],
#  [2,
#   6434,
#   3323,
#   3632,
#   984,
#   1,
#   736,
#   4986,
#   7,
#   5,
#   1012,
#   398,
#   18,
#   1,
#   140,
#   71,
#   974,
#   461,
#   15,
#   10172,
#   13,
#   5,
#   543,
#   321,
#   540,
#   4,
#   1191,
#   308,
#   7818,
#   222,
#   13968,
#   13,
#   68,
#   132,
#   224,
#   1758,
#   6,
#   5614,
#   540,
#   4,
#   4987,
#   629,
#   540,
#   222,
#   50,
#   17],
#  [2,
#   575,
#   6434,
#   1,
#   3323,
#   3632,
#   4,
#   1,
#   132,
#   736,
#   4986,
#   374,
#   7,
#   5,
#   1012,
#   398,
#   3,
#   1,
#   140,
#   71,
#   974,
#   753,
#   461,
#   15,
#   10172,
#   13,
#   5,
#   543,
#   321,
#   540,
#   4,
#   1191,
#   308,
#   18,
#   7818,
#   222,
#   13968,
#   13,
#   68,
#   132,
#   224,
#   1758,
#   6,
#   315,
#   3632,
#   80,
#   117,
#   540,
#   4,
#   1,
#   4987,
#   629,
#   8,
#   2542,
#   222,
#   209,
#   4988,
#   17],
#  [25,
#   6434,
#   26690,
#   3632,
#   4,
#   1,
#   736,
#   4986,
#   22,
#   5,
#   1012,
#   398,
#   3,
#   1,
#   140,
#   71,
#   974,
#   461,
#   15,
#   10172,
#   13,
#   10,
#   543,
#   321,
#   540,
#   4,
#   1191,
#   328,
#   4113,
#   2462,
#   13968,
#   13,
#   1132,
#   132,
#   224,
#   1758,
#   6,
#   15,
#   540,
#   4,
#   4987,
#   629,
#   2542,
#   222,
#   4988,
#   17],
#  [2, 262, 10, 4010],
#  [2, 262, 10, 4010],
#  [2, 262, 10, 26691, 10173],
#  [2, 262, 34, 4010],
#  [2, 262, 10, 336, 4010],
#  [3, 262, 10, 4010],
#  [10,
#   1468,
#   589,
#   2951,
#   974,
#   9,
#   140,
#   71,
#   7,
#   173,
#   1,
#   1419,
#   1,
#   54,
#   2498,
#   4505,
#   1,
#   8900,
#   58,
#   8,
#   2151,
#   2499,
#   27,
#   6158,
#   3,
#   128,
#   1,
#   18,
#   1648,
#   380,
#   131],
#  [10,
#   1468,
#   589,
#   2951,
#   974,
#   9,
#   140,
#   71,
#   7,
#   173,
#   1,
#   1419,
#   1,
#   54,
#   2498,
#   4505,
#   1,
#   1256,
#   2151,
#   2499,
#   128,
#   1,
#   18,
#   1648,
#   509,
#   131],
#  [1, 1468, 589, 2951, 974, 9, 140, 71, 7, 173],
#  [10,
#   1468,
#   589,
#   2951,
#   974,
#   9,
#   140,
#   71,
#   7,
#   173,
#   1,
#   1419,
#   1,
#   54,
#   2498,
#   4505,
#   1,
#   8900,
#   58,
#   1122,
#   2151,
#   2499,
#   27,
#   6158,
#   3,
#   128,
#   1,
#   491,
#   86,
#   380,
#   131],
#  [10,
#   517,
#   1468,
#   589,
#   2951,
#   974,
#   9,
#   1036,
#   140,
#   254,
#   71,
#   7,
#   173,
#   1,
#   374,
#   1419,
#   1,
#   1020,
#   54,
#   556,
#   2498,
#   4505,
#   1,
#   8900,
#   3,
#   58,
#   541,
#   8,
#   2151,
#   2499,
#   27,
#   6158,
#   3,
#   128,
#   1,
#   18,
#   1648,
#   380,
#   131],
#  [1,
#   1468,
#   589,
#   2951,
#   974,
#   9,
#   140,
#   71,
#   7,
#   173,
#   1,
#   1419,
#   1,
#   54,
#   2498,
#   4505,
#   1,
#   8900,
#   58,
#   60,
#   2151,
#   2499,
#   4,
#   6158,
#   5,
#   128,
#   14,
#   18,
#   1648,
#   136,
#   131],
#  [323,
#   193,
#   10174,
#   3208,
#   3,
#   22,
#   99,
#   53,
#   4011,
#   23,
#   40,
#   1,
#   231,
#   29,
#   174,
#   46,
#   40,
#   53,
#   5361,
#   478,
#   20,
#   107,
#   520,
#   9,
#   62,
#   140,
#   509,
#   131,
#   224,
#   4012,
#   51,
#   536,
#   61,
#   705],
#  [609,
#   193,
#   10174,
#   496,
#   3,
#   22,
#   99,
#   53,
#   4011,
#   23,
#   40,
#   1,
#   18807,
#   29,
#   115,
#   189,
#   40,
#   53,
#   1944,
#   478,
#   20,
#   107,
#   520,
#   9,
#   62,
#   2422,
#   3319,
#   131,
#   224,
#   4012,
#   51,
#   536,
#   61,
#   705],
#  [323,
#   193,
#   10174,
#   496,
#   3,
#   22,
#   82,
#   194,
#   53,
#   4011,
#   23,
#   57,
#   1,
#   3104,
#   29,
#   115,
#   189,
#   40,
#   53,
#   5361,
#   478,
#   20,
#   107,
#   520,
#   9,
#   62,
#   2422,
#   4989,
#   509,
#   131,
#   5,
#   224,
#   5361,
#   2,
#   22,
#   51,
#   536,
#   61,
#   705],
#  [323,
#   193,
#   10174,
#   3208,
#   3,
#   22,
#   99,
#   53,
#   4011,
#   23,
#   40,
#   1,
#   231,
#   99,
#   174,
#   46,
#   40,
#   53,
#   5150,
#   52,
#   20,
#   2075,
#   520,
#   9,
#   62,
#   140,
#   509,
#   131,
#   224,
#   4012,
#   51,
#   536,
#   61,
#   705],
#  [323,
#   193,
#   10174,
#   3208,
#   3,
#   22,
#   99,
#   53,
#   4011,
#   23,
#   40,
#   1,
#   1616,
#   231,
#   29,
#   174,
#   40,
#   46,
#   37,
#   40,
#   53,
#   5361,
#   5881,
#   1326,
#   20,
#   107,
#   520,
#   9,
#   104,
#   62,
#   1,
#   140,
#   24,
#   509,
#   131,
#   224,
#   4012,
#   463,
#   51,
#   536,
#   61,
#   930,
#   705],
#  [60,
#   193,
#   10174,
#   3208,
#   3,
#   22,
#   99,
#   53,
#   4011,
#   23,
#   57,
#   1,
#   1261,
#   345,
#   174,
#   46,
#   114,
#   53,
#   5361,
#   478,
#   20,
#   107,
#   520,
#   9,
#   62,
#   140,
#   509,
#   131,
#   14,
#   4012,
#   51,
#   536,
#   61,
#   930],
#  [224,
#   22290,
#   665,
#   3,
#   14,
#   311,
#   1538,
#   433,
#   140,
#   4990,
#   3324,
#   13,
#   34,
#   18808,
#   6750,
#   13969],
#  [665, 3, 14, 311, 1538, 433, 140, 4990, 3324, 13, 34, 18808, 6750, 13969],
#  [224, 8901, 665, 3, 14, 311, 1538, 1697, 140, 4990, 13, 34, 18808, 24239],
#  [224,
#   791,
#   665,
#   3,
#   14,
#   6751,
#   311,
#   1538,
#   433,
#   140,
#   3324,
#   13,
#   34,
#   4990,
#   60,
#   13969],
#  [224,
#   300,
#   22290,
#   665,
#   9,
#   3,
#   286,
#   14,
#   311,
#   884,
#   1538,
#   1201,
#   433,
#   140,
#   4990,
#   24240,
#   3324,
#   1220,
#   13,
#   34,
#   3537,
#   18808,
#   4509,
#   6750,
#   13969],
#  [224,
#   1079,
#   665,
#   3,
#   14,
#   60,
#   1992,
#   311,
#   1538,
#   26692,
#   3324,
#   4,
#   34,
#   2355,
#   6750,
#   13969],
#  [323,
#   140,
#   5362,
#   2302,
#   458,
#   183,
#   25,
#   76,
#   7819,
#   40,
#   2387,
#   4,
#   89,
#   83,
#   40,
#   109,
#   40,
#   2,
#   99,
#   76,
#   24,
#   2,
#   56,
#   3376,
#   168,
#   19,
#   109,
#   151,
#   12,
#   9,
#   6162,
#   21,
#   2688,
#   968,
#   23,
#   5,
#   1660,
#   7275,
#   151,
#   12,
#   9,
#   286,
#   253,
#   795,
#   752,
#   3,
#   219,
#   488,
#   3,
#   539,
#   4],
#  [323,
#   140,
#   5362,
#   2302,
#   458,
#   2,
#   412,
#   4988,
#   4,
#   50,
#   83,
#   40,
#   2387,
#   40,
#   2,
#   29,
#   24,
#   2,
#   56,
#   12,
#   168,
#   109,
#   151,
#   12,
#   9,
#   6162,
#   21,
#   15,
#   2688,
#   7,
#   25,
#   23,
#   5,
#   457,
#   7275,
#   151,
#   12,
#   9,
#   286,
#   253,
#   247,
#   752,
#   3,
#   219,
#   488,
#   3],
#  [323,
#   140,
#   5362,
#   2302,
#   458,
#   183,
#   25,
#   76,
#   7819,
#   40,
#   2387,
#   4,
#   89,
#   83,
#   40,
#   109,
#   40,
#   2,
#   99,
#   24,
#   2,
#   56,
#   3376,
#   168,
#   109,
#   151,
#   12,
#   9,
#   6162,
#   21,
#   2688,
#   7,
#   25,
#   23,
#   5,
#   1660,
#   7275,
#   151,
#   12,
#   9,
#   286,
#   253,
#   795,
#   752,
#   3,
#   219,
#   488,
#   3,
#   72,
#   4],
#  [323,
#   140,
#   5362,
#   2302,
#   458,
#   183,
#   25,
#   76,
#   7819,
#   40,
#   2387,
#   4,
#   89,
#   83,
#   40,
#   109,
#   40,
#   2,
#   99,
#   76,
#   24,
#   200,
#   56,
#   3376,
#   168,
#   19,
#   109,
#   151,
#   12,
#   9,
#   1539,
#   21,
#   2688,
#   968,
#   23,
#   10,
#   1660,
#   7275,
#   151,
#   12,
#   9,
#   1925,
#   253,
#   173,
#   455,
#   3,
#   219,
#   488,
#   3,
#   539,
#   4],
#  [5882,
#   323,
#   140,
#   5362,
#   2302,
#   458,
#   183,
#   25,
#   76,
#   7819,
#   40,
#   2387,
#   4,
#   69,
#   89,
#   83,
#   40,
#   136,
#   109,
#   40,
#   2,
#   99,
#   55,
#   76,
#   24,
#   2,
#   55,
#   56,
#   3376,
#   168,
#   19,
#   109,
#   151,
#   12,
#   9,
#   6162,
#   21,
#   2688,
#   18,
#   968,
#   23,
#   5,
#   1660,
#   63,
#   7275,
#   2,
#   151,
#   12,
#   9,
#   286,
#   253,
#   795,
#   328,
#   752,
#   3,
#   219,
#   109,
#   488,
#   3,
#   539,
#   4],
#  [86,
#   140,
#   5362,
#   2302,
#   458,
#   183,
#   25,
#   76,
#   7819,
#   40,
#   2387,
#   4,
#   89,
#   25,
#   40,
#   344,
#   43,
#   2,
#   99,
#   76,
#   24,
#   2,
#   56,
#   3376,
#   168,
#   19,
#   109,
#   151,
#   12,
#   9,
#   6162,
#   21,
#   2688,
#   968,
#   23,
#   5,
#   745,
#   7275,
#   161,
#   9,
#   60,
#   286,
#   62,
#   282,
#   752,
#   3,
#   219,
#   488,
#   3,
#   539,
#   4],
#  [336,
#   391,
#   166,
#   2500,
#   90,
#   1967,
#   149,
#   7820,
#   218,
#   3,
#   38,
#   454,
#   32,
#   1,
#   886,
#   4,
#   593,
#   3,
#   301,
#   67,
#   90,
#   126,
#   654,
#   8,
#   9490],
#  [336,
#   391,
#   166,
#   2500,
#   90,
#   1967,
#   149,
#   7820,
#   218,
#   3,
#   38,
#   164,
#   1,
#   886,
#   4,
#   593,
#   3,
#   301,
#   67,
#   90,
#   126,
#   654,
#   8,
#   9490],
#  [336,
#   391,
#   166,
#   2500,
#   90,
#   1967,
#   149,
#   26693,
#   218,
#   3,
#   38,
#   454,
#   32,
#   1,
#   886,
#   4,
#   593,
#   3,
#   301,
#   67,
#   90,
#   126,
#   654,
#   8,
#   26694],
#  [336,
#   391,
#   166,
#   2500,
#   90,
#   1967,
#   149,
#   7820,
#   218,
#   3,
#   38,
#   454,
#   782,
#   1,
#   886,
#   4,
#   593,
#   30,
#   301,
#   1992,
#   90,
#   126,
#   654,
#   8,
#   9490],
#  [336,
#   391,
#   166,
#   2500,
#   90,
#   1967,
#   149,
#   7820,
#   218,
#   12,
#   3,
#   121,
#   38,
#   1881,
#   454,
#   32,
#   397,
#   1,
#   886,
#   4,
#   55,
#   593,
#   3,
#   301,
#   67,
#   90,
#   126,
#   654,
#   3917,
#   8,
#   9490],
#  [336,
#   391,
#   166,
#   2500,
#   4,
#   1967,
#   532,
#   7820,
#   218,
#   3,
#   38,
#   454,
#   32,
#   1,
#   886,
#   4,
#   789,
#   3,
#   301,
#   67,
#   41,
#   126,
#   654,
#   8,
#   9490],
#  [140, 71, 2228, 56, 4, 4013, 181, 77, 54, 1190, 1366, 415, 576, 456, 13970],
#  [140, 71, 1366, 56, 4, 4013, 181, 77, 54, 1190, 1366, 1215, 576, 456, 13970],
#  [140, 71, 38, 56, 4, 4013, 181, 77, 54, 1190, 1366, 415, 2, 456, 26695, 16],
#  [140, 1509, 2228, 56, 4, 4013, 181, 86, 54, 1190, 1366, 415, 190, 456, 13970],
#  [181,
#   140,
#   71,
#   201,
#   2228,
#   2464,
#   56,
#   1262,
#   4,
#   4013,
#   1989,
#   181,
#   77,
#   54,
#   1190,
#   3464,
#   1366,
#   415,
#   576,
#   456,
#   13970],
#  [140,
#   17,
#   2228,
#   3633,
#   4,
#   4013,
#   181,
#   823,
#   60,
#   1968,
#   1366,
#   415,
#   576,
#   456,
#   13970],
#  [77, 140, 540, 668, 35, 36, 16, 13971],
#  [77, 2422, 540, 668, 35, 36, 16, 13971],
#  [77, 140, 540, 668, 35, 730, 435, 13971],
#  [77, 140, 540, 668, 35, 36, 16, 13971],
#  [72, 77, 140, 540, 668, 35, 36, 16, 13971],
#  [60],
# ...
#   2,
#   22,
#   68,
#   3919,
#   17,
#   1,
#   54,
#   266,
#   13,
#   420,
#   418,
#   25,
#   369,
#   48,
#   243,
#   230,
#   114,
#   1,
#   348,
#   1183,
#   4,
#   3920,
#   345,
#   3,
#   55,
#   1444,
#   4,
#   696,
#   17,
#   132,
#   344,
#   3,
#   931,
#   3328,
#   5149,
#   787,
#   14019,
#   223,
#   69,
#   20,
#   2233],
#  [140, 3059, 7, 206, 55, 1927],
#  [6155, 3059, 7, 55, 136],
#  [5151, 3059, 7, 55, 5891],
#  [140, 3059, 7, 206, 5161, 1927],
#  [140, 3059, 7, 206, 174, 55, 1927],
#  [140, 3059, 7, 206, 78, 1927],
#  [140,
#   71,
#   594,
#   70,
#   26,
#   620,
#   718,
#   250,
#   3,
#   3819,
#   3820,
#   84,
#   10214,
#   1,
#   243,
#   83,
#   32,
#   5,
#   507,
#   783,
#   206,
#   46],
#  [140,
#   71,
#   594,
#   70,
#   271,
#   620,
#   250,
#   3,
#   3819,
#   3820,
#   84,
#   10214,
#   1,
#   243,
#   83,
#   32,
#   5,
#   507,
#   41,
#   26,
#   206,
#   46],
#  [140,
#   71,
#   594,
#   70,
#   26,
#   620,
#   718,
#   250,
#   3,
#   846,
#   3820,
#   84,
#   10214,
#   1,
#   243,
#   83,
#   32,
#   5,
#   507,
#   783,
#   206,
#   46],
#  [140,
#   71,
#   594,
#   70,
#   26,
#   620,
#   718,
#   250,
#   3,
#   3819,
#   3820,
#   84,
#   10214,
#   1,
#   243,
#   83,
#   32,
#   5,
#   1719,
#   783,
#   206,
#   86],
#  [140,
#   71,
#   594,
#   70,
#   26,
#   620,
#   719,
#   718,
#   250,
#   3,
#   15,
#   3819,
#   3820,
#   23,
#   84,
#   10214,
#   1,
#   241,
#   243,
#   83,
#   32,
#   5,
#   7284,
#   507,
#   783,
#   55,
#   206,
#   46],
#  [140,
#   37,
#   403,
#   69,
#   26,
#   620,
#   718,
#   250,
#   13,
#   3819,
#   3820,
#   84,
#   10214,
#   1,
#   243,
#   83,
#   32,
#   5,
#   507,
#   783,
#   206,
#   46],
#  [2,
#   223,
#   38,
#   58,
#   1811,
#   14,
#   1685,
#   253,
#   15,
#   239,
#   57,
#   2008,
#   441,
#   4021,
#   6766,
#   39,
#   49,
#   23,
#   45,
#   5,
#   167,
#   595,
#   2,
#   565,
#   50,
#   62,
#   140,
#   24,
#   129,
#   14021,
#   26,
#   149,
#   138],
#  [2,
#   223,
#   38,
#   58,
#   1811,
#   14,
#   1685,
#   395,
#   57,
#   1,
#   2008,
#   7,
#   31,
#   4,
#   39,
#   49,
#   23,
#   128,
#   5,
#   167,
#   595,
#   2,
#   146,
#   3,
#   50,
#   62,
#   140,
#   24,
#   129,
#   14021,
#   26,
#   149,
#   138],
#  [2,
#   22,
#   3,
#   38,
#   58,
#   4,
#   1811,
#   14,
#   1685,
#   4,
#   19,
#   57,
#   1,
#   3380,
#   441,
#   1089,
#   39,
#   49,
#   23,
#   45,
#   5,
#   167,
#   595,
#   2,
#   146,
#   3,
#   50,
#   62,
#   8,
#   1,
#   2422,
#   4211,
#   24,
#   129,
#   388,
#   1247,
#   138,
#   26,
#   149],
#  [2,
#   23,
#   38,
#   58,
#   1811,
#   14,
#   1685,
#   253,
#   15,
#   117,
#   57,
#   2008,
#   441,
#   4021,
#   2009,
#   39,
#   49,
#   23,
#   45,
#   5,
#   167,
#   595,
#   2,
#   565,
#   50,
#   62,
#   140,
#   24,
#   78,
#   14021,
#   26,
#   149,
#   138],
#  [393,
#   2,
#   223,
#   38,
#   58,
#   1811,
#   164,
#   14,
#   1685,
#   253,
#   15,
#   1,
#   239,
#   57,
#   2008,
#   441,
#   58,
#   4021,
#   6766,
#   1853,
#   39,
#   49,
#   23,
#   45,
#   5,
#   167,
#   595,
#   2,
#   565,
#   50,
#   1187,
#   62,
#   123,
#   140,
#   24,
#   129,
#   14021,
#   27,
#   26,
#   149,
#   138],
#  [2,
#   223,
#   38,
#   58,
#   1811,
#   14,
#   1685,
#   27,
#   15,
#   239,
#   57,
#   2008,
#   26,
#   4021,
#   978,
#   39,
#   49,
#   144,
#   45,
#   68,
#   167,
#   595,
#   2,
#   565,
#   84,
#   62,
#   140,
#   24,
#   129,
#   14021,
#   26,
#   149,
#   138],
#  [10, 7, 2153, 27, 12, 612, 21, 17, 1698, 140, 35, 36, 16, 14022],
#  [331, 55, 27, 12, 612, 21, 1698, 140, 35, 36, 16, 14022],
#  [7, 15, 55, 27, 12, 612, 21, 1698, 140, 35, 1208, 14022],
#  [10, 7, 2153, 27, 12, 612, 21, 17, 101, 101, 35, 36, 16, 14022],
#  [4, 10, 7, 2153, 27, 12, 612, 21, 17, 101, 101, 35, 36, 16, 14022],
#  [12],
#  [606, 73, 140, 71, 7, 267],
#  [606, 73, 140, 71, 7, 267],
#  [606, 73, 140, 71, 7, 267],
#  [606, 73, 140, 71, 2010, 267],
#  [606, 73, 140, 71, 7, 34, 267],
#  [606, 73, 140, 71, 14, 267],
#  [190, 17, 68, 305, 408, 263, 1773, 5892, 8, 140, 71, 134, 108, 18836],
#  [190, 17, 68, 305, 408, 263, 1773, 5892, 8, 140, 71, 134, 108, 18836],
#  [190, 17, 68, 305, 408, 263, 1773, 5892, 8, 140, 71],
#  [190, 17, 68, 305, 408, 263, 1773, 5892, 8, 140, 71, 134, 108, 18836],
#  [236, 190, 17, 68, 305, 408, 263, 1773, 5892, 8, 140, 71, 134, 108, 18836],
#  [40],
#  [3211, 1168, 1357, 6, 317, 83, 26, 46],
#  [3211, 1168, 1357, 6, 129, 83, 7, 46],
#  [3211, 1591, 1357, 6, 129, 83, 7, 46],
#  [3211, 1168, 1357, 43, 317, 83, 26, 46],
#  [3211, 1168, 1357, 6, 1634, 317, 83, 1342, 26, 46],
#  [3211, 1168, 3540, 6, 317, 83, 26, 46],
#  [18837, 2154, 27, 1, 3268, 18837],
#  [2154, 27, 1, 3268],
#  [2154, 26755, 1, 26756],
#  [18837, 11, 27, 1, 3268, 18837],
#  [60, 2154, 7, 27, 1, 3268, 60],
#  [60, 2154, 26757, 1, 26758, 60],
#  [4022, 2, 22, 140, 3, 3152, 21, 58],
#  [28, 632, 2, 22, 140, 3, 3152, 21, 58],
#  [28, 632, 2, 22, 2422, 6755, 3, 3152, 21, 13],
#  [4022, 2, 22, 140, 3, 475, 21, 58],
#  [1, 4022, 2, 22, 140, 3, 227, 3152, 21, 58],
#  [4022, 2, 22, 140, 49, 3152, 312, 58],
#  [140, 71, 438, 24, 144, 5162, 1343, 23, 224, 22312, 74, 645, 40],
#  [140, 71, 438, 24, 144, 5162, 18838, 106, 224, 22312, 11, 7, 645, 40],
#  [140, 71, 2837, 24, 144, 10215, 1343, 23, 2393, 24262, 74, 645, 40],
#  [140, 71, 438, 24, 144, 5162, 1343, 23, 224, 4, 74, 645, 40],
#  [140, 6, 71, 438, 24, 144, 301, 5162, 1343, 23, 224, 22312, 74, 645, 40],
#  [140, 71, 438, 24, 55, 5162, 1343, 23, 224, 4, 74, 645, 40],
#  [1698,
#   240,
#   89,
#   292,
#   27,
#   6,
#   1,
#   140,
#   83,
#   17,
#   5,
#   507,
#   2,
#   55,
#   22,
#   5,
#   2357,
#   9,
#   232,
#   62,
#   2,
#   2234,
#   10216,
#   24,
#   103,
#   7,
#   51,
#   239,
#   3,
#   235,
#   11,
#   604,
#   11,
#   211,
#   1906,
#   46,
#   4,
#   136,
#   66,
#   49,
#   2,
#   50,
#   11],
#  [1698,
#   286,
#   196,
#   27,
#   1,
#   140,
#   83,
#   17,
#   5,
#   507,
#   2,
#   55,
#   146,
#   62,
#   2,
#   2234,
#   10216,
#   24,
#   103,
#   7,
#   51,
#   239,
#   3,
#   235,
#   11,
#   604,
#   11,
#   211,
#   1906,
#   46,
#   4,
#   7,
#   136,
#   66,
#   49,
#   2,
#   50,
#   11],
#  [1698,
#   240,
#   89,
#   292,
#   27,
#   6,
#   1,
#   140,
#   83,
#   17,
#   5,
#   507,
#   2,
#   55,
#   22,
#   5,
#   2357,
#   9,
#   232,
#   62,
#   2,
#   2234,
#   10216,
#   24,
#   103,
#   7,
#   51,
#   239,
#   3,
#   235,
#   11,
#   604,
#   11,
#   22313,
#   46,
#   4,
#   136,
#   66,
#   49,
#   2,
#   50,
#   11],
#  [1698,
#   240,
#   697,
#   292,
#   27,
#   6,
#   1,
#   140,
#   2354,
#   17,
#   5,
#   507,
#   2,
#   55,
#   22,
#   5,
#   2357,
#   9,
#   232,
#   62,
#   2,
#   2234,
#   10216,
#   3821,
#   103,
#   7,
#   51,
#   250,
#   3,
#   235,
#   11,
#   604,
#   11,
#   211,
#   1906,
#   560,
#   4,
#   136,
#   66,
#   49,
#   2,
#   50,
#   11],
#  [1698,
#   240,
#   89,
#   292,
#   27,
#   6,
#   1,
#   140,
#   6,
#   83,
#   17,
#   23,
#   5,
#   507,
#   2,
#   55,
#   22,
#   5,
#   4220,
#   2357,
#   9,
#   232,
#   62,
#   563,
#   2,
#   2234,
#   10216,
#   24,
#   103,
#   7,
#   51,
#   239,
#   3,
#   235,
#   11,
#   395,
#   604,
#   11,
#   997,
#   211,
#   1906,
#   46,
#   437,
#   4,
#   136,
#   4,
#   66,
#   49,
#   2,
#   50,
#   11],
#  [1698,
#   240,
#   89,
#   292,
#   145,
#   6,
#   1,
#   140,
#   83,
#   17,
#   5,
#   507,
#   120,
#   200,
#   22,
#   5,
#   2357,
#   9,
#   232,
#   62,
#   2,
#   2234,
#   10216,
#   24,
#   103,
#   7,
#   103,
#   239,
#   25,
#   235,
#   11,
#   37,
#   11,
#   211,
#   1906,
#   149,
#   4,
#   136,
#   69,
#   49,
#   2,
#   50,
#   11],
#  [1,
#   22314,
#   7,
#   14,
#   121,
#   960,
#   6,
#   543,
#   217,
#   140,
#   2845,
#   59,
#   19,
#   251,
#   3,
#   72,
#   27,
#   1,
#   386,
#   834,
#   6,
#   27,
#   1,
#   2130,
#   90,
#   5625,
#   35,
#   36,
#   16,
#   18839],
#  [1,
#   22314,
#   7,
#   14,
#   121,
#   543,
#   3,
#   45,
#   140,
#   2845,
#   59,
#   19,
#   251,
#   3,
#   72,
#   27,
#   1,
#   386,
#   834,
#   6,
#   27,
#   1,
#   3107,
#   2130,
#   35,
#   36,
#   16,
#   18839],
#  [22314,
#   7,
#   14,
#   121,
#   960,
#   6,
#   543,
#   217,
#   64,
#   140,
#   2845,
#   59,
#   19,
#   251,
#   3,
#   72,
#   27,
#   1,
#   386,
#   178,
#   6,
#   27,
#   1,
#   2130,
#   1883,
#   35,
#   730,
#   16,
#   26759],
#  [1,
#   101,
#   7,
#   14,
#   121,
#   960,
#   6,
#   543,
#   217,
#   140,
#   2845,
#   59,
#   19,
#   251,
#   3,
#   72,
#   27,
#   1,
#   386,
#   834,
#   6,
#   27,
#   1,
#   2130,
#   90,
#   5625,
#   35,
#   36,
#   16,
#   18839],
#  [1904,
#   1,
#   101,
#   7,
#   14,
#   121,
#   960,
#   6,
#   543,
#   217,
#   140,
#   2845,
#   59,
#   19,
#   251,
#   3,
#   72,
#   27,
#   1,
#   386,
#   834,
#   6,
#   27,
#   1,
#   2130,
#   90,
#   5625,
#   35,
#   36,
#   16,
#   18839],
#  [15],
#  [43, 2, 99, 3, 582, 70, 1207, 50, 553, 19, 308, 13],
#  [43, 2, 99, 3, 582, 70, 1207, 50, 553, 19, 308],
#  [43, 2, 99, 3, 582, 70, 1, 1207, 18, 553, 19, 308],
#  [43, 2, 99, 3, 582, 70, 1207, 50, 553, 19, 189, 13],
#  [43, 2, 99, 63, 3, 582, 70, 1207, 50, 153, 553, 19, 308, 13],
#  [43, 2, 99, 512, 582, 70, 1207, 50, 553, 19, 308, 13],
#  [736,
#   135,
#   138,
#   665,
#   3,
#   1698,
#   405,
#   4,
#   140,
#   374,
#   327,
#   12,
#   299,
#   27,
#   1,
#   4360,
#   124,
#   1,
#   77,
#   303,
#   974,
#   64,
#   5,
#   6767,
#   3,
#   5893,
#   151,
#   12,
#   9,
#   2032,
#   21,
#   571,
#   1,
#   649],
#  [138,
#   7,
#   5,
#   736,
#   135,
#   665,
#   3,
#   1698,
#   405,
#   4,
#   140,
#   721,
#   327,
#   12,
#   299,
#   27,
#   1,
#   4360,
#   871,
#   74,
#   1,
#   77,
#   303,
#   974,
#   151,
#   12,
#   9,
#   2032,
#   21,
#   571,
#   14,
#   649],
#  [665, 1698, 405, 4, 140],
#  [736,
#   135,
#   138,
#   665,
#   3,
#   1698,
#   405,
#   4,
#   140,
#   374,
#   327,
#   12,
#   299,
#   27,
#   1,
#   244,
#   124,
#   132,
#   282,
#   303,
#   974,
#   64,
#   5,
#   6767,
#   3,
#   5893,
#   151,
#   12,
#   9,
#   2032,
#   21,
#   571,
#   644,
#   649],
#  [736,
#   135,
#   138,
#   790,
#   665,
#   3,
#   1995,
#   1698,
#   315,
#   405,
#   4,
#   140,
#   34,
#   374,
#   327,
#   12,
#   44,
#   299,
#   9,
#   27,
#   1,
#   4360,
#   124,
#   1,
#   1167,
#   77,
#   303,
#   974,
#   64,
#   5,
#   6767,
#   2504,
#   3,
#   84,
#   5893,
#   151,
#   12,
#   9,
#   2032,
#   21,
#   571,
#   1,
#   3329,
#   649],
#  [736,
#   722,
#   138,
#   665,
#   3,
#   2174,
#   3381,
#   4,
#   1698,
#   374,
#   239,
#   12,
#   299,
#   27,
#   1,
#   4360,
#   124,
#   1,
#   77,
#   303,
#   257,
#   64,
#   5,
#   6767,
#   6,
#   5893,
#   86,
#   12,
#   193,
#   2032,
#   21,
#   571,
#   1,
#   649],
#  [2011, 3054, 10217, 5000, 10218, 140, 33],
#  [2011, 3054, 10217, 5000, 10218, 140, 33],
#  [24263, 4821, 10217, 26760, 10218, 26761, 4989, 33],
#  [2011, 2846, 10217, 5000, 10218, 140, 33],
#  [2011, 3054, 5, 10217, 69, 5000, 9, 10218, 140, 33],
#  [2011, 1952, 10217, 4, 10218, 140, 33],
#  [2127, 1866, 21, 8, 140, 44, 4, 264],
#  [2127, 1866, 21, 8, 140, 44, 4, 264],
#  [2127, 1866, 21, 13, 1, 1099, 6, 44, 4, 264],
#  [2127, 1866, 21, 8, 140, 44, 69, 264],
#  [2127, 360, 1866, 21, 8, 140, 44, 7285, 4, 264],
#  [2127, 82, 21, 8, 140, 44, 4, 264],
#  [462,
#   1833,
#   17,
#   2645,
#   5370,
#   4,
#   140,
#   68,
#   73,
#   290,
#   12,
#   384,
#   22,
#   3,
#   2896,
#   361,
#   283,
#   525,
#   317,
#   26,
#   1,
#   780,
#   5371,
#   2847,
#   13,
#   21,
#   67,
#   90,
#   50,
#   143,
#   69,
#   1,
#   176,
#   6,
#   104],
#  [519,
#   835,
#   17,
#   2645,
#   5370,
#   4,
#   140,
#   68,
#   73,
#   290,
#   12,
#   126,
#   22,
#   3,
#   2896,
#   361,
#   283,
#   525,
#   317,
#   26,
#   1,
#   780,
#   5371,
#   90,
#   262,
#   21,
#   67,
#   90,
#   50,
#   143,
#   69,
#   1,
#   176,
#   6,
#   104],
#  [519,
#   1833,
#   17,
#   2645,
#   5370,
#   4,
#   140,
#   68,
#   73,
#   290,
#   12,
#   45,
#   25,
#   22,
#   3,
#   2896,
#   361,
#   283,
#   525,
#   317,
#   26,
#   1,
#   780,
#   5371,
#   26762,
#   13,
#   21,
#   67,
#   90,
#   50,
#   143,
#   69,
#   1,
#   176,
#   6,
#   104],
#  [462,
#   1833,
#   17,
#   2011,
#   5370,
#   4,
#   140,
#   68,
#   73,
#   290,
#   12,
#   384,
#   22,
#   3,
#   2896,
#   361,
#   283,
#   2464,
#   103,
#   26,
#   1,
#   780,
#   5371,
#   2847,
#   13,
#   21,
#   67,
#   15,
#   50,
#   143,
#   69,
#   1,
#   176,
#   6,
#   104],
#  [68,
#   668,
#   80,
#   27,
#   23,
#   1833,
#   17,
#   5,
#   2645,
#   5370,
#   4,
#   140,
#   68,
#   73,
#   290,
#   12,
#   727,
#   80,
#   47,
#   22,
#   3,
#   2896,
#   361,
#   283,
#   525,
#   317,
#   26,
#   1,
#   264,
#   780,
#   5371,
#   164,
#   2847,
#   4,
#   13,
#   460,
#   21,
#   67,
#   90,
#   23,
#   50,
#   143,
#   69,
#   1,
#   176,
#   264,
#   6,
#   104],
#  [462,
#   1833,
#   17,
#   2645,
#   5370,
#   4,
#   140,
#   50,
#   73,
#   290,
#   12,
#   106,
#   22,
#   69,
#   2896,
#   164,
#   283,
#   525,
#   317,
#   26,
#   1,
#   780,
#   5371,
#   2847,
#   13,
#   83,
#   67,
#   55,
#   262,
#   143,
#   69,
#   1,
#   176,
#   6,
#   104],
#  [66,
#   42,
#   11,
#   76,
#   5,
#   368,
#   166,
#   176,
#   166,
#   2,
#   99,
#   1,
#   1928,
#   3060,
#   6,
#   342,
#   17,
#   405,
#   4221,
#   4,
#   1,
#   727,
#   10219,
#   464,
#   13,
#   10,
#   1663,
#   140,
#   5163,
#   22315,
#   98,
#   285,
#   61,
#   5,
#   63,
#   119,
#   56,
#   3,
#   178,
#   17,
#   1,
#   1020,
#   131,
#   9,
#   22316,
#   78,
#   44,
#   6,
#   14,
#   1021,
#   2131,
#   24264,
#   35,
#   36,
#   16,
#   18840],
#  [66,
#   705,
#   11,
#   27,
#   166,
#   176,
#   166,
#   2,
#   99,
#   1,
#   6174,
#   3060,
#   6,
#   342,
#   17,
#   405,
#   4221,
#   4,
#   1,
#   727,
#   10219,
#   464,
#   13,
#   10,
#   1663,
#   140,
#   5163,
#   22315,
#   98,
#   285,
#   61,
#   5,
#   63,
#   119,
#   56,
#   3,
#   178,
#   17,
#   1,
#   1020,
#   131,
#   3,
#   128,
#   369,
#   78,
#   44,
#   6,
#   14,
#   321,
#   2131,
#   24264,
#   35,
#   36,
#   16,
#   18840],
#  [176,
#   166,
#   2,
#   99,
#   1,
#   6174,
#   3060,
#   6,
#   342,
#   17,
#   405,
#   4221,
#   4,
#   727,
#   10219,
#   464,
#   13,
#   10,
#   1663,
#   140,
#   2007,
#   22315,
#   98,
#   285,
#   61,
#   5,
#   63],
#  [66,
#   42,
#   11,
#   76,
#   5,
#   368,
#   166,
#   176,
#   166,
#   2,
#   99,
#   1,
#   1928,
#   3060,
#   6,
#   342,
#   17,
#   101,
#   4,
#   1,
#   727,
#   101,
#   13,
#   10,
#   1663,
#   101,
#   5163,
#   101,
#   98,
#   285,
#   61,
#   5,
#   63,
#   119,
#   56,
#   3,
#   178,
#   17,
#   1,
#   1020,
#   131,
#   9,
#   22316,
#   78,
#   44,
#   6,
#   14,
#   1021,
#   2131,
#   101,
#   35,
#   36,
#   16,
#   18840],
#  [648,
#   66,
#   42,
#   11,
#   76,
#   5,
#   368,
#   166,
#   176,
#   166,
#   2,
#   99,
#   1,
#   1928,
#   3060,
#   6,
#   342,
#   17,
#   101,
#   4,
#   1,
#   727,
#   101,
#   13,
#   10,
#   1663,
#   101,
#   5163,
#   101,
#   98,
#   285,
#   61,
#   5,
#   63,
#   119,
#   56,
#   3,
#   178,
#   17,
#   1,
#   1020,
#   131,
#   9,
#   22316,
#   78,
#   44,
#   6,
#   14,
#   1021,
#   2131,
#   101,
#   35,
#   36,
#   16,
#   18840],
#  [1],
#  [2102, 4, 1772, 8916, 74, 63, 9, 5, 134, 108, 18841],
#  [3001, 4, 1772, 10220, 74, 63, 9, 5, 134, 108, 18841],
#  [2102, 4, 1, 1772, 6, 8917, 74, 63, 9, 992, 108, 26763],
#  [2102, 4, 1772, 8916, 74, 63, 9, 5, 134, 108, 18841],
#  [40, 2102, 4, 1772, 8916, 74, 63, 9, 5, 134, 108, 18841],
#  [29],
#  [131, 140, 273],
#  [131, 140, 273],
#  [131, 140, 273],
#  [131, 140, 60],
#  [131, 33, 140, 273],
#  [131, 4, 273],
#  [10,
#   5894,
#   42,
#   76,
#   1,
#   339,
#   18842,
#   6,
#   2688,
#   2,
#   22,
#   294,
#   10,
#   62,
#   370,
#   137,
#   2,
#   119,
#   56,
#   3,
#   20,
#   244,
#   43,
#   1,
#   14023,
#   556,
#   8,
#   2425,
#   2736,
#   7,
#   40,
#   149,
#   40,
#   140],
#  [10,
#   5894,
#   29,
#   1,
#   339,
#   8405,
#   6,
#   2688,
#   183,
#   294,
#   62,
#   370,
#   137,
#   953,
#   30,
#   3,
#   43,
#   1,
#   14023,
#   556,
#   8,
#   2425,
#   2736,
#   29,
#   40,
#   149,
#   40,
#   140],
#  [15,
#   5894,
#   29,
#   1,
#   339,
#   24265,
#   24265,
#   183,
#   294,
#   62,
#   370,
#   137,
#   953,
#   30,
#   43,
#   26764,
#   556,
#   8,
#   1,
#   2425,
#   6,
#   2736,
#   29,
#   40,
#   149,
#   40,
#   26765],
#  [10,
#   5894,
#   42,
#   76,
#   1,
#   339,
#   18842,
#   6,
#   2688,
#   2,
#   22,
#   326,
#   10,
#   62,
#   370,
#   137,
#   2,
#   119,
#   56,
#   3,
#   20,
#   3469,
#   43,
#   1,
#   14023,
#   556,
#   8,
#   2425,
#   2736,
#   7,
#   40,
#   1079,
#   40,
#   140],
#  [10,
#   5894,
#   42,
#   76,
#   24266,
#   1,
#   339,
#   573,
#   18842,
#   6,
#   18,
#   2688,
#   2,
#   22,
#   1383,
#   294,
#   10,
#   62,
#   370,
#   62,
#   137,
#   2,
#   69,
#   119,
#   56,
#   3,
#   20,
#   244,
#   43,
#   1,
#   14023,
#   556,
#   8,
#   2425,
#   2736,
#   7,
#   40,
#   149,
#   103,
#   40,
#   140],
#  [10,
#   5894,
#   249,
#   76,
#   1,
#   339,
#   18842,
#   9,
#   2688,
#   90,
#   22,
#   294,
#   10,
#   62,
#   370,
#   137,
#   2,
#   119,
#   56,
#   3,
#   20,
#   244,
#   43,
#   1,
#   14023,
#   556,
#   8,
#   4222,
#   2736,
#   7,
#   40,
#   149,
#   17,
#   1459],
#  [140, 71, 7, 701, 136],
#  [140, 71, 7, 55, 136],
#  [140, 71, 7, 298, 559],
#  [140, 71, 7, 701, 577],
#  [140, 71, 7, 206, 701, 136],
#  [140, 395, 7, 701, 136],
#  [320,
#   83,
#   7,
#   5,
#   5001,
#   1350,
#   436,
#   389,
#   1,
#   175,
#   12,
#   22,
#   322,
#   111,
#   1488,
#   7,
#   249,
#   5001,
#   14024,
#   9,
#   61,
#   39,
#   45,
#   984,
#   921,
#   10,
#   7,
#   4658],
#  [320,
#   83,
#   7,
#   5,
#   5001,
#   1350,
#   436,
#   389,
#   1,
#   175,
#   12,
#   22,
#   322,
#   111,
#   1488,
#   7,
#   249,
#   5001,
#   14024,
#   9,
#   61,
#   39,
#   45,
#   361,
#   921,
#   331,
#   4658],
#  [320,
#   83,
#   7,
#   5,
#   132,
#   1350,
#   436,
#   12,
#   22,
#   322,
#   389,
#   5,
#   175,
#   111,
#   1488,
#   7,
#   249,
#   26766,
#   9,
#   61,
#   39,
#   45,
#   3,
#   921],
#  [320,
#   83,
#   7,
#   5,
#   5001,
#   1350,
#   436,
#   389,
#   1,
#   175,
#   41,
#   22,
#   322,
#   8,
#   1488,
#   26,
#   249,
#   5001,
#   14024,
#   9,
#   61,
#   39,
#   45,
#   984,
#   921,
#   10,
#   7,
#   4658],
#  [320,
#   83,
#   7,
#   5,
#   5001,
#   1350,
#   649,
#   436,
#   389,
#   1,
#   175,
#   12,
#   22,
#   294,
#   322,
#   111,
#   1488,
#   1342,
#   7,
#   249,
#   132,
#   5001,
#   1738,
#   14024,
#   9,
#   61,
#   328,
#   39,
#   45,
#   57,
#   984,
#   921,
#   10,
#   7,
#   4658],
#  [320,
#   83,
#   7,
#   5,
#   2890,
#   1350,
#   436,
#   389,
#   1,
#   743,
#   12,
#   22,
#   322,
#   111,
#   1488,
#   496,
#   249,
#   5001,
#   14024,
#   9,
#   61,
#   39,
#   45,
#   375,
#   1481,
#   10,
#   7,
#   4658],
#  [939],
#  [939],
#  [1, 4023],
#  [939],
#  [9, 939],
#  [6],
#  [2052, 221, 9, 68, 140, 13],
#  [2052, 13, 9, 68, 140],
#  [2052, 28, 140],
#  [2052, 221, 17, 68, 140, 13],
#  [26767, 117, 283, 221, 9, 68, 140, 13],
#  [2052, 221, 9, 1, 140, 13],
#  [2800,
#   405,
#   1037,
#   70,
#   703,
#   2959,
#   9,
#   140,
#   71,
#   43,
#   12,
#   2897,
#   287,
#   128,
#   11,
#   2646,
#   9,
#   420,
#   61,
#   5,
#   1702],
#  [2800,
#   405,
#   1037,
#   70,
#   703,
#   2959,
#   9,
#   140,
#   71,
#   43,
#   12,
#   1470,
#   128,
#   11,
#   2646,
#   17,
#   1,
#   420,
#   61,
#   5,
#   1702],
#  ...]

# %%
max_sequence_length = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)
max_sequence_length
# Out:
# 166

# %%
words_count = len(tokenizer.word_index) + 1
words_count
# Out:
# 33784

# %%
X_train, X_test, y_train, y_test = train_test_split(padded_sequences,y, test_size=0.2, random_state=42)

# %% [markdown]
# # **RNN**

# %%
model = Sequential([
    Embedding(words_count, 80, input_length=max_sequence_length),
    SimpleRNN(64),
    Dense(4, activation='softmax')
])
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy'
, metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1850/1850 ━━━━━━━━━━━━━━━━━━━━ 29s 13ms/step - accuracy: 0.5047 - loss: 0.4707
# Epoch 2/5
# 1850/1850 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.8828 - loss: 0.1610
# Epoch 3/5
# 1850/1850 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9389 - loss: 0.0852
# Epoch 4/5
# 1850/1850 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9563 - loss: 0.0603
# Epoch 5/5
# 1850/1850 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9590 - loss: 0.0530

# %%
print(model.evaluate(X_train, y_train))
print(model.evaluate(X_test, y_test))
# Out:
# 1850/1850 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9672 - loss: 0.0385
# [0.03822153061628342, 0.968308687210083]
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8592 - loss: 0.2101
# [0.20881770551204681, 0.8606081008911133]

# %% [markdown]
# # **LSTM**

# %%
lstm_model = Sequential([
    Embedding(words_count, 50, input_length=max_sequence_length),
    LSTM(64),
    Dense(4, activation='softmax')
])
lstm_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
lstm_model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1850/1850 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.5070 - loss: 0.4641
# Epoch 2/5
# 1850/1850 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8625 - loss: 0.1751
# Epoch 3/5
# 1850/1850 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9093 - loss: 0.1108
# Epoch 4/5
# 1850/1850 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.9319 - loss: 0.0813
# Epoch 5/5
# 1850/1850 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.9426 - loss: 0.0649

# %%
print(lstm_model.evaluate(X_train, y_train))
print(lstm_model.evaluate(X_test, y_test))
# Out:
# 1850/1850 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9559 - loss: 0.0517
# [0.05171939358115196, 0.9562470316886902]
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8828 - loss: 0.1586
# [0.1563572883605957, 0.8868243098258972]
